# %%
import pandas as pd

# %%
'''
Function counts the total number of times each page has been visited in all user journeys

Parameters:
data: DataFrame with cleaned user journey data in column 'user_journey'
target_column: default set to 'user_journey' - do not set as another column

Returns:
A series containing counts of unique values from a list with all web page appearances in user journey
'''

def page_counts(data, target_column='user_journey', subscription_select=None):
    
    # Empty list to store '-' seperated values in strings of 'user_journey'
    mega_list = []
    
    # Loop to iterate through each row of the DataFrame
    for index, row in data.iterrows():
        
        if subscription_select == None:
            # Extracts values from target_column containing hyphen-separated strings and stores them in a list
            page_list = row[target_column].split('-')
            mega_list.extend(page_list)
        elif row['subscription_type'] == subscription_select:
            # Extracts values of specified subscription type from target_column and stores them in a list
            page_list = row[target_column].split('-')
            mega_list.extend(page_list)
        
    
    # mega_list is converted to a series and unique values counted
    page_counts = pd.Series(mega_list).value_counts()
    
    return page_counts

# %%
'''
Counts the number of times a page appears in a users journey, only will count the page once per journey

Parameters:
data: DataFrame with cleaned user journey data in column 'user_journey'
target_column: default set to 'user_journey' - do not set as another column

Returns:
A series containing counts of unique values from a list with total appearances of a page in user journey
'''

def page_presence(data, target_column='user_journey', subscription_select=None):
    
    # Empty list to store string values each time they appear in user journey 
    mega_list = []
    
    # Iterates through rows in a DataFrame (data)
    for index, row in data.iterrows():
        
        if subscription_select == None:
            # Extracts values from target_column containing hyphen-separated strings and stores them in a list
            page_list = row[target_column].split('-')
        elif row['subscription_type'] == subscription_select:
            # Extracts values of specified subscription type from target_column and stores them in a list
            page_list = row[target_column].split('-')
        
        
        # Returns set of 'page_list' removing duplicate values in the list
        unique_pages = list(set(page_list))
        # Adds them to a cumulative list (mega_list)
        mega_list.extend(unique_pages)
    
    # mega_list is converted to a series and unique values counted
    page_presence = pd.Series(mega_list).value_counts()
    
    return page_presence

# %%
'''
Looks at every page and records which pages the user goes to next. Can specify the subscription type and
what page you want to see subsequent destination pages from.

Parameters:
data: DataFrame with cleaned user journey data in column 'user_journey'
target_column: default set to 'user_journey' - do not set as another column
page: default set to None, will return all key value pairs. Can specify a specific web page to view

Returns:
Dictionaries key value pairs for either all pages or a specific page. Each dictionary key for a page has
another dictionary within it that has the keys as subsequent page visits from that page, the keys show 
how often this has happened per user
'''
def page_destinations(data, target_column='user_journey', subscription_select=None, page=None): 
    
    # Initialize a dictionary to store the counts
    page_destinations = {}
    
    # Iterates through rows in a DataFrame (data)
    for index, row in data.iterrows():
        
         # if elif statement handles selecting either all journeys or only for a specific subscription type
        if subscription_select == None:
           # Extracts all values from target_column and stores them in a list 
            page_list = row[target_column].split('-')
        elif row['subscription_type'] == subscription_select:
            # Extracts values of specified subscription type from target_column and stores them in a list
            page_list = row[target_column].split('-')
        
        # Iterate through the list to count occurrences of the next strings
        for i in range(len(page_list) - 1):
            current_string = page_list[i]
            next_string = page_list[i + 1]

            # Check if the current string is already in the dictionary
            if current_string not in page_destinations:
                page_destinations[current_string] = {}
            
            # Count occurrences of the next string
            if next_string in page_destinations[current_string]:
                page_destinations[current_string][next_string] += 1
            else:
                page_destinations[current_string][next_string] = 1
    
    if page is None:
        return page_destinations
    else:
        if page in page_destinations:
            return page_destinations[page]
        else:
            return print('Page not found')

# %%
'''
Looks at the most popular sequence of page view for a specified number of pages

Parameters:
data: DataFrame with cleaned user journey data in column 'user_journey'
target_column: default set to 'user_journey' - do not set as another column
subscription_select: Default is None which will select all results. 
                     Can be 'Yearly', 'Monthly' or 'Quarterly' to only look at certain subscription types
start_page: Default will select all results.
            Can be a string value of desired start page for subsequent sequences of pages
run: Default set at 2 - criteria for the number of pages in sequence to view

Returns:
Sorted dictionary in descending order of page sequences. Keys are the sequence of pages, values are occurances
'''

def page_sequences(data, target_column='user_journey', subscription_select=None, start_page=None, run=2):
    
    # Initialize a dictionary to store all the counts of sequences in individual user journys
    sequences_count = {}
    
    # Iterates through rows in a DataFrame (data)
    for index, row in data.iterrows():
        
        # if elif statement handles selecting either all journeys or only for a specific subscription type
        if subscription_select == None:
            # Extracts all values from target_column and stores them in a list 
            page_list = row[target_column].split('-') 
        elif row['subscription_type'] == subscription_select:
            # Extracts values of specified subscription type from target_column and stores them in a list
            page_list = row[target_column].split('-')   
            
        # Empty list to store page sequences for each iteration of user journey in main for loop
        user_page_sequence = []
        
        # Iterates through list of pages and slices the specified amount of page sequences
        for i in range(len(page_list) - (run-1)):
            combination = page_list[i:i+run]
            string_comb = '-'.join(combination)
            
            # If page sequence for individual user has not occured, adds the sequence to a list 
            if string_comb not in user_page_sequence and start_page == None:
                user_page_sequence.append(string_comb)
            elif string_comb not in user_page_sequence and page_list[i] == start_page:
                user_page_sequence.append(string_comb)
                
        # Adds count of individual users sequence to overall count of all sequences
        for sequence in user_page_sequence:
            if sequence not in sequences_count:
                sequences_count[sequence] = 1
            else:
                sequences_count[sequence] += 1
    
    # Creates a new dictionsary sorting the results into descending order
    sorted_sequences = {k: v for k, v in sorted(sequences_count.items(), key=lambda item: item[1], reverse=True)}
    
    return sorted_sequences

# %%
'''
Calculates the average amount of pages a user goes through (excluding repeated sequential pages from 
data cleaning)

Parameters:
data: DataFrame with cleaned user journey data in column 'user_journey'
target_column: default set to 'user_journey' - do not set as another column

Returns:
Returns the average number of pages a users goes through as an integer
'''
def journey_length(data, target_column='user_journey'):
    
    total_page_views = 0
    
    for index, row in data.iterrows():
        page_list = row[target_column].split('-')
        total_page_views += len(page_list)
    
    average_journey = (total_page_views / len(data[target_column]))
    
    return average_journey

# %%
# Import csv file with the cleaned user journey data into a pandas DataFrame
df_user_journeys = pd.read_csv('user_journey_23_01_to_23_03_CLEANED.csv')
df_user_journeys
# Out:
#       user_id subscription_type  \
# 0        1516            Yearly
# 1        3395            Yearly
# 2       10107            Yearly
# 3       11145           Monthly
# 4       12400           Monthly
# ...       ...               ...
# 1432   509060            Yearly
# 1433   509061            Yearly
# 1434   509085            Yearly
# 1435   509095            Yearly
# 1436   509096            Yearly
#
#                                            user_journey
# 0     Log in-Homepage-Log in-Other-Log in-Other-Sign...
# 1     Log in-Sign up-Log in-Pricing-Sign up-Homepage...
# 2     Homepage-Resources center-Other-Career tracks-...
# 3     Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4     Homepage-Career tracks-Sign up-Log in-Career t...
# ...                                                 ...
# 1432                                              Other
# 1433                                             Coupon
# 1434                                             Coupon
# 1435                                              Other
# 1436                                Coupon-Other-Coupon
#
# [1437 rows x 3 columns]

# %%
page_counts(df_user_journeys, subscription_select='Quarterly')
# Out:
# Log in                      134
# Homepage                    127
# Sign up                      89
# Checkout                     68
# Career tracks                61
# Courses                      56
# Pricing                      35
# Career track certificate     28
# Other                        22
# Course certificate           18
# Resources center             16
# Coupon                        7
# Upcoming courses              5
# Success stories               4
# About us                      1
# dtype: int64

# %%
page_sequences(df_user_journeys, start_page='Pricing', run=4)
# Out:
# {'Pricing-Checkout-Pricing-Checkout': 56,
#  'Pricing-Checkout-Homepage-Pricing': 47,
#  'Pricing-Sign up-Homepage-Pricing': 26,
#  'Pricing-Courses-Pricing-Courses': 25,
#  'Pricing-Homepage-Pricing-Homepage': 25,
#  'Pricing-Log in-Homepage-Log in': 22,
#  'Pricing-Sign up-Pricing-Sign up': 21,
#  'Pricing-Courses-Homepage-Courses': 18,
#  'Pricing-Career tracks-Pricing-Career tracks': 17,
#  'Pricing-Career tracks-Courses-Career tracks': 17,
#  'Pricing-Homepage-Pricing-Checkout': 16,
#  'Pricing-Log in-Homepage-Pricing': 16,
#  'Pricing-Career tracks-Homepage-Career tracks': 15,
#  'Pricing-Homepage-Pricing-Log in': 14,
#  'Pricing-Homepage-Pricing-Courses': 13,
#  'Pricing-Log in-Pricing-Log in': 13,
#  'Pricing-Checkout-Log in-Homepage': 13,
#  'Pricing-Courses-Career tracks-Courses': 13,
#  'Pricing-Checkout-Log in-Checkout': 12,
#  'Pricing-Sign up-Homepage-Sign up': 11,
#  'Pricing-Courses-Homepage-Pricing': 11,
#  'Pricing-Career track certificate-Pricing-Career track certificate': 10,
#  'Pricing-Career tracks-Sign up-Career tracks': 9,
#  'Pricing-Sign up-Log in-Homepage': 9,
#  'Pricing-Resources center-Pricing-Resources center': 9,
#  'Pricing-Career track certificate-Homepage-Pricing': 8,
#  'Pricing-Career tracks-Homepage-Pricing': 8,
#  'Pricing-Checkout-Homepage-Log in': 8,
#  'Pricing-Career track certificate-Career tracks-Career track certificate': 8,
#  'Pricing-Checkout-Pricing-Sign up': 7,
#  'Pricing-Homepage-Sign up-Homepage': 7,
#  'Pricing-Log in-Checkout-Log in': 7,
#  'Pricing-Courses-Career track certificate-Courses': 7,
#  'Pricing-Homepage-Pricing-Career tracks': 7,
#  'Pricing-Homepage-Courses-Pricing': 7,
#  'Pricing-Courses-Pricing-Checkout': 7,
#  'Pricing-Homepage-Career tracks-Courses': 7,
#  'Pricing-Checkout-Homepage-Career tracks': 6,
#  'Pricing-Checkout-Courses-Pricing': 6,
#  'Pricing-Homepage-Log in-Homepage': 6,
#  'Pricing-Checkout-Pricing-Homepage': 6,
#  'Pricing-Homepage-Log in-Checkout': 5,
#  'Pricing-Career tracks-Sign up-Homepage': 5,
#  'Pricing-Checkout-Homepage-Sign up': 5,
#  'Pricing-Checkout-Other-Pricing': 5,
#  'Pricing-Sign up-Log in-Sign up': 5,
#  'Pricing-Career tracks-Career track certificate-Career tracks': 5,
#  'Pricing-Homepage-Pricing-Resources center': 5,
#  'Pricing-Checkout-Career tracks-Pricing': 5,
#  'Pricing-Courses-Homepage-Career tracks': 5,
#  'Pricing-Sign up-Career tracks-Pricing': 5,
#  'Pricing-Homepage-Pricing-Coupon': 5,
#  'Pricing-Courses-Sign up-Log in': 5,
#  'Pricing-Career track certificate-Career tracks-Pricing': 5,
#  'Pricing-Career track certificate-Sign up-Career track certificate': 5,
#  'Pricing-Sign up-Checkout-Log in': 5,
#  'Pricing-Courses-Pricing-Sign up': 5,
#  'Pricing-Courses-Career tracks-Homepage': 5,
#  'Pricing-Checkout-Homepage-Courses': 5,
#  'Pricing-Career tracks-Pricing-Homepage': 5,
#  'Pricing-Checkout-Log in-Pricing': 4,
#  'Pricing-Checkout-Pricing-Log in': 4,
#  'Pricing-Log in-Other-Log in': 4,
#  'Pricing-Log in-Other-Pricing': 4,
#  'Pricing-Checkout-Sign up-Pricing': 4,
#  'Pricing-Career tracks-Pricing-Sign up': 4,
#  'Pricing-Homepage-Pricing-Sign up': 4,
#  'Pricing-Course certificate-Homepage-Pricing': 4,
#  'Pricing-Checkout-Courses-Career tracks': 4,
#  'Pricing-Resources center-Courses-Resources center': 4,
#  'Pricing-Sign up-Pricing-Checkout': 4,
#  'Pricing-Log in-Sign up-Log in': 4,
#  'Pricing-Sign up-Log in-Other': 4,
#  'Pricing-Career track certificate-Pricing-Checkout': 4,
#  'Pricing-Sign up-Log in-Checkout': 4,
#  'Pricing-Sign up-Courses-Sign up': 4,
#  'Pricing-Courses-Pricing-Homepage': 4,
#  'Pricing-Career track certificate-Course certificate-Career track certificate': 4,
#  'Pricing-Sign up-Checkout-Homepage': 4,
#  'Pricing-Homepage-Courses-Career tracks': 4,
#  'Pricing-Career tracks-Pricing-Checkout': 4,
#  'Pricing-Sign up-Homepage-Log in': 3,
#  'Pricing-Homepage-Courses-Homepage': 3,
#  'Pricing-Courses-Log in-Checkout': 3,
#  'Pricing-Career tracks-Courses-Homepage': 3,
#  'Pricing-Courses-Career tracks-Pricing': 3,
#  'Pricing-Upcoming courses-Courses-Upcoming courses': 3,
#  'Pricing-Sign up-Pricing-Log in': 3,
#  'Pricing-Courses-Upcoming courses-Courses': 3,
#  'Pricing-Checkout-Pricing-Other': 3,
#  'Pricing-Courses-Log in-Courses': 3,
#  'Pricing-Checkout-Coupon-Checkout': 3,
#  'Pricing-Career track certificate-Homepage-Career track certificate': 3,
#  'Pricing-Course certificate-Career track certificate-Course certificate': 3,
#  'Pricing-Other-Pricing-Log in': 3,
#  'Pricing-Courses-Course certificate-Courses': 3,
#  'Pricing-Resources center-Pricing-Courses': 3,
#  'Pricing-Career track certificate-Courses-Career track certificate': 3,
#  'Pricing-Resources center-Homepage-Pricing': 3,
#  'Pricing-Checkout-Coupon-Homepage': 3,
#  'Pricing-Sign up-Other-Pricing': 3,
#  'Pricing-Log in-Pricing-Checkout': 3,
#  'Pricing-Homepage-Courses-Sign up': 3,
#  'Pricing-Homepage-Career tracks-Homepage': 3,
#  'Pricing-Career track certificate-Sign up-Courses': 3,
#  'Pricing-Career track certificate-Career tracks-Sign up': 3,
#  'Pricing-Courses-Pricing-Career tracks': 3,
#  'Pricing-Checkout-Courses-Homepage': 3,
#  'Pricing-Career track certificate-Course certificate-Courses': 3,
#  'Pricing-Checkout-Pricing-Courses': 3,
#  'Pricing-Upcoming courses-Courses-Pricing': 3,
#  'Pricing-Sign up-Courses-Pricing': 3,
#  'Pricing-Checkout-Resources center-Pricing': 3,
#  'Pricing-Courses-Career track certificate-Pricing': 2,
#  'Pricing-Career tracks-Courses-Career track certificate': 2,
#  'Pricing-Success stories-Pricing-Success stories': 2,
#  'Pricing-Upcoming courses-Pricing-Upcoming courses': 2,
#  'Pricing-Upcoming courses-Pricing-Checkout': 2,
#  'Pricing-Checkout-Other-Checkout': 2,
#  'Pricing-Log in-Pricing-Sign up': 2,
#  'Pricing-Checkout-Coupon-Log in': 2,
#  'Pricing-Checkout-Homepage-Checkout': 2,
#  'Pricing-Homepage-Other-Homepage': 2,
#  'Pricing-Career tracks-Pricing-Log in': 2,
#  'Pricing-Career tracks-Log in-Pricing': 2,
#  'Pricing-Resources center-Log in-Homepage': 2,
#  'Pricing-Career track certificate-Homepage-Courses': 2,
#  'Pricing-Resources center-Pricing-Homepage': 2,
#  'Pricing-Checkout-Career tracks-Sign up': 2,
#  'Pricing-Career track certificate-Sign up-Course certificate': 2,
#  'Pricing-Courses-Other-Courses': 2,
#  'Pricing-Checkout-Course certificate-Pricing': 2,
#  'Pricing-Courses-Pricing-Other': 2,
#  'Pricing-Log in-Checkout-Coupon': 2,
#  'Pricing-Log in-Pricing-Homepage': 2,
#  'Pricing-Homepage-Log in-Pricing': 2,
#  'Pricing-Course certificate-Log in-Other': 2,
#  'Pricing-Resources center-Other-Homepage': 2,
#  'Pricing-Sign up-Pricing-Homepage': 2,
#  'Pricing-Checkout-Resources center-Other': 2,
#  'Pricing-Sign up-Homepage-Career tracks': 2,
#  'Pricing-Resources center-Pricing-Checkout': 2,
#  'Pricing-Homepage-Courses-Checkout': 2,
#  'Pricing-Checkout-Homepage-Career track certificate': 2,
#  'Pricing-Career tracks-Homepage-Sign up': 2,
#  'Pricing-Other-Resources center-Courses': 2,
#  'Pricing-Checkout-Log in-Other': 2,
#  'Pricing-Homepage-Career tracks-Log in': 2,
#  'Pricing-Resources center-Courses-Homepage': 2,
#  'Pricing-Career track certificate-Courses-Career tracks': 2,
#  'Pricing-Career track certificate-Sign up-Log in': 2,
#  'Pricing-Career track certificate-Resources center-Course certificate': 2,
#  'Pricing-Other-Pricing-Other': 2,
#  'Pricing-Sign up-Homepage-Courses': 2,
#  'Pricing-Sign up-Log in-Career tracks': 2,
#  'Pricing-Course certificate-Career track certificate-Career tracks': 2,
#  'Pricing-Courses-Resources center-Pricing': 2,
#  'Pricing-Career track certificate-Upcoming courses-Career track certificate': 2,
#  'Pricing-Career tracks-Sign up-Pricing': 2,
#  'Pricing-Courses-Resources center-Courses': 2,
#  'Pricing-Homepage-Career track certificate-Sign up': 2,
#  'Pricing-Sign up-Career track certificate-Pricing': 2,
#  'Pricing-Course certificate-Sign up-Course certificate': 2,
#  'Pricing-Resources center-Upcoming courses-Resources center': 2,
#  'Pricing-Courses-Sign up-Courses': 2,
#  'Pricing-Career tracks-Courses-Course certificate': 2,
#  'Pricing-Sign up-Checkout-Pricing': 2,
#  'Pricing-Courses-Homepage-Sign up': 2,
#  'Pricing-Courses-Sign up-Homepage': 2,
#  'Pricing-Homepage-Courses-Resources center': 2,
#  'Pricing-Career tracks-Courses-Pricing': 2,
#  'Pricing-Checkout-Sign up-Homepage': 2,
#  'Pricing-Homepage-Career track certificate-Homepage': 2,
#  'Pricing-Homepage-Career tracks-Coupon': 2,
#  'Pricing-Checkout-Career track certificate-Career tracks': 2,
#  'Pricing-Course certificate-Pricing-Career track certificate': 2,
#  'Pricing-Career track certificate-Courses-Pricing': 2,
#  'Pricing-Homepage-Sign up-Coupon': 2,
#  'Pricing-Course certificate-Courses-Course certificate': 2,
#  'Pricing-Courses-Career track certificate-Career tracks': 2,
#  'Pricing-Courses-Sign up-Pricing': 2,
#  'Pricing-Career track certificate-Courses-Homepage': 2,
#  'Pricing-Log in-Other-Checkout': 2,
#  'Pricing-Career tracks-Sign up-Log in': 2,
#  'Pricing-Homepage-Sign up-Pricing': 2,
#  'Pricing-Resources center-Other-Resources center': 2,
#  'Pricing-Sign up-Career tracks-Courses': 2,
#  'Pricing-Sign up-Pricing-Courses': 2,
#  'Pricing-Other-Pricing-Sign up': 2,
#  'Pricing-Sign up-Pricing-Resources center': 2,
#  'Pricing-Log in-Sign up-Homepage': 2,
#  'Pricing-Other-Homepage-Log in': 2,
#  'Pricing-Checkout-Other-Log in': 1,
#  'Pricing-Sign up-Career tracks-Homepage': 1,
#  'Pricing-Homepage-Career track certificate-Career tracks': 1,
#  'Pricing-Career tracks-Other-Homepage': 1,
#  'Pricing-Career track certificate-Upcoming courses-Career tracks': 1,
#  'Pricing-Course certificate-Pricing-Log in': 1,
#  'Pricing-Log in-Homepage-Course certificate': 1,
#  'Pricing-Instructors-Pricing-Success stories': 1,
#  'Pricing-Success stories-Homepage-Success stories': 1,
#  'Pricing-Homepage-Pricing-Upcoming courses': 1,
#  'Pricing-Courses-Resources center-Upcoming courses': 1,
#  'Pricing-Other-Pricing-Career tracks': 1,
#  'Pricing-Other-Log in-Pricing': 1,
#  'Pricing-Other-Courses-Sign up': 1,
#  'Pricing-Sign up-Log in-Coupon': 1,
#  'Pricing-Career track certificate-Log in-Checkout': 1,
#  'Pricing-Sign up-Career track certificate-Career tracks': 1,
#  'Pricing-Log in-Homepage-Courses': 1,
#  'Pricing-Career track certificate-Coupon-Log in': 1,
#  'Pricing-Log in-Homepage-Career track certificate': 1,
#  'Pricing-Log in-Career tracks-Homepage': 1,
#  'Pricing-Career tracks-Log in-Homepage': 1,
#  'Pricing-Log in-Sign up-Checkout': 1,
#  'Pricing-Log in-Career tracks-Log in': 1,
#  'Pricing-Log in-Checkout-Resources center': 1,
#  'Pricing-Course certificate-Pricing-Checkout': 1,
#  'Pricing-Resources center-Pricing-Career track certificate': 1,
#  'Pricing-Other-Homepage-Career track certificate': 1,
#  'Pricing-Career track certificate-Career tracks-Resources center': 1,
#  'Pricing-Log in-Pricing-Career tracks': 1,
#  'Pricing-Career tracks-Pricing-Resources center': 1,
#  'Pricing-Resources center-Pricing-Upcoming courses': 1,
#  'Pricing-Upcoming courses-Career tracks-Resources center': 1,
#  'Pricing-Resources center-Log in-Coupon': 1,
#  'Pricing-Career track certificate-Career tracks-Log in': 1,
#  'Pricing-Resources center-Pricing-Log in': 1,
#  'Pricing-Career track certificate-Log in-Homepage': 1,
#  'Pricing-Career tracks-Career track certificate-Sign up': 1,
#  'Pricing-Career tracks-Resources center-Pricing': 1,
#  'Pricing-Courses-Log in-Career track certificate': 1,
#  'Pricing-Homepage-Sign up-Courses': 1,
#  'Pricing-Courses-Log in-Career tracks': 1,
#  'Pricing-Log in-Instructors-Pricing': 1,
#  'Pricing-Resources center-Other-Log in': 1,
#  'Pricing-Log in-Career track certificate-Success stories': 1,
#  'Pricing-Log in-Courses-Log in': 1,
#  'Pricing-Courses-Pricing-Log in': 1,
#  'Pricing-Log in-Sign up-Other': 1,
#  'Pricing-Homepage-Career tracks-Sign up': 1,
#  'Pricing-Log in-Checkout-Pricing': 1,
#  'Pricing-Log in-Homepage-Sign up': 1,
#  'Pricing-Success stories-Blog-Homepage': 1,
#  'Pricing-Log in-Resources center-Other': 1,
#  'Pricing-Log in-Career track certificate-Pricing': 1,
#  'Pricing-Courses-Sign up-Coupon': 1,
#  'Pricing-Log in-Resources center-Log in': 1,
#  'Pricing-Upcoming courses-Log in-Homepage': 1,
#  'Pricing-Coupon-Log in-Coupon': 1,
#  'Pricing-Log in-Coupon-Homepage': 1,
#  'Pricing-Coupon-Homepage-Career tracks': 1,
#  'Pricing-Course certificate-Upcoming courses-Courses': 1,
#  'Pricing-Courses-Career tracks-Sign up': 1,
#  'Pricing-Courses-Log in-Homepage': 1,
#  'Pricing-Coupon-Log in-Checkout': 1,
#  'Pricing-Log in-Coupon-Log in': 1,
#  'Pricing-Homepage-Log in-Other': 1,
#  'Pricing-Sign up-Coupon-Homepage': 1,
#  'Pricing-Courses-Course certificate-Upcoming courses': 1,
#  'Pricing-Checkout-Pricing-Career tracks': 1,
#  'Pricing-Checkout-Log in-Coupon': 1,
#  'Pricing-Checkout-Homepage-Resources center': 1,
#  'Pricing-Career tracks-Sign up-Courses': 1,
#  'Pricing-Resources center-Log in-Resources center': 1,
#  'Pricing-Courses-Pricing-Upcoming courses': 1,
#  'Pricing-Sign up-Pricing-Career track certificate': 1,
#  'Pricing-Career tracks-Course certificate-Homepage': 1,
#  'Pricing-Sign up-Coupon-Log in': 1,
#  'Pricing-Homepage-Pricing-Career track certificate': 1,
#  'Pricing-Career track certificate-Log in-Course certificate': 1,
#  'Pricing-Log in-Career track certificate-Log in': 1,
#  'Pricing-Checkout-Coupon-Courses': 1,
#  'Pricing-Courses-Homepage-Success stories': 1,
#  'Pricing-Success stories-Pricing-Homepage': 1,
#  'Pricing-Courses-Checkout-Log in': 1,
#  'Pricing-Checkout-Courses-Sign up': 1,
#  'Pricing-Career tracks-Career track certificate-Career track certific': 1,
#  'Pricing-Courses-Upcoming courses-Pricing': 1,
#  'Pricing-Career tracks-Pricing-Career track certificate': 1,
#  'Pricing-Homepage-Other-Courses': 1,
#  'Pricing-Sign up-Pricing-Career tracks': 1,
#  'Pricing-Courses-Checkout-Courses': 1,
#  'Pricing-Sign up-Homepage-Career track certificate': 1,
#  'Pricing-Checkout-Course certificate-Sign up': 1,
#  'Pricing-Homepage-Course certificate-Homepage': 1,
#  'Pricing-Homepage-Course certificate-Pricing': 1,
#  'Pricing-Career track certificate-Homepage-Course certificate': 1,
#  'Pricing-Career track certificate-Pricing-Resources center': 1,
#  'Pricing-About us-Pricing-Homepage': 1,
#  'Pricing-Homepage-About us-Homepage': 1,
#  'Pricing-Course certificate-Courses-Other': 1,
#  'Pricing-Resources center-Other-Career track certificate': 1,
#  'Pricing-Upcoming courses-Resources center-Homepage': 1,
#  'Pricing-Other-Coupon-Homepage': 1,
#  'Pricing-Blog-Pricing-Blog': 1,
#  'Pricing-Blog-Pricing-Courses': 1,
#  'Pricing-Blog-Pricing-Career tracks': 1,
#  'Pricing-Log in-Homepage-Checkout': 1,
#  'Pricing-Career tracks-Courses-Sign up': 1,
#  'Pricing-Sign up-Success stories-Pricing': 1,
#  'Pricing-Success stories-Checkout-Log in': 1,
#  'Pricing-Resources center-Sign up-Pricing': 1,
#  'Pricing-Homepage-Sign up-Course certificate': 1,
#  'Pricing-Log in-Sign up-Career tracks': 1,
#  'Pricing-Homepage-Pricing-Other': 1,
#  'Pricing-Other-Pricing-Checkout': 1,
#  'Pricing-Upcoming courses-Homepage-Career track certificate': 1,
#  'Pricing-Checkout-Career track certificate-Pricing': 1,
#  'Pricing-Career track certificate-Other-Pricing': 1,
#  'Pricing-Coupon-Other-Resources center': 1,
#  'Pricing-Courses-Coupon-Homepage': 1,
#  'Pricing-Sign up-Career tracks-Sign up': 1,
#  'Pricing-Checkout-Other-Courses': 1,
#  'Pricing-Courses-Resources center-Homepage': 1,
#  'Pricing-Career track certificate-Homepage-Coupon': 1,
#  'Pricing-Homepage-Resources center-Pricing': 1,
#  'Pricing-Resources center-Career track certificate-Resources center': 1,
#  'Pricing-Courses-Other-Pricing': 1,
#  'Pricing-Courses-Upcoming courses-Resources center': 1,
#  'Pricing-Resources center-Instructors-Pricing': 1,
#  'Pricing-Career track certificate-Career tracks-Homepage': 1,
#  'Pricing-Checkout-Pricing-Career track certificate': 1,
#  'Pricing-Resources center-Log in-Checkout': 1,
#  'Pricing-Course certificate-Coupon-Log in': 1,
#  'Pricing-Career track certificate-Other-Career tracks': 1,
#  'Pricing-Resources center-Career track certificate-Pricing': 1,
#  'Pricing-Career track certificate-Pricing-Career tracks': 1,
#  'Pricing-Career tracks-Courses-Resources center': 1,
#  'Pricing-Success stories-Career track certificate-Pricing': 1,
#  'Pricing-Career track certificate-Success stories-Courses': 1,
#  'Pricing-Career track certificate-Homepage-Career tracks': 1,
#  'Pricing-Career tracks-Resources center-Career tracks': 1,
#  'Pricing-Homepage-Checkout-Pricing': 1,
#  'Pricing-Checkout-Homepage-About us': 1,
#  'Pricing-Course certificate-Sign up-Courses': 1,
#  'Pricing-Course certificate-Checkout-Log in': 1,
#  'Pricing-Checkout-Upcoming courses-Pricing': 1,
#  'Pricing-Career tracks-Course certificate-Career tracks': 1,
#  'Pricing-Courses-Career track certificate-Course certificate': 1,
#  'Pricing-Sign up-Courses-Resources center': 1,
#  'Pricing-Career track certificate-Pricing-Sign up': 1,
#  'Pricing-Course certificate-Upcoming courses-Coupon': 1,
#  'Pricing-Courses-Career track certificate-Instructors': 1,
#  'Pricing-Course certificate-Courses-Pricing': 1,
#  'Pricing-Other-Courses-Other': 1,
#  'Pricing-Coupon-Pricing-Checkout': 1,
#  'Pricing-Checkout-Log in-Courses': 1,
#  'Pricing-Other-Career tracks-Log in': 1,
#  'Pricing-Courses-Log in-Sign up': 1,
#  'Pricing-Resources center-Courses-Upcoming courses': 1,
#  'Pricing-Homepage-Upcoming courses-Homepage': 1,
#  'Pricing-Career track certificate-Pricing-Upcoming courses': 1,
#  'Pricing-Courses-Pricing-Career track certificate': 1,
#  'Pricing-Upcoming courses-Career track certificate-Courses': 1,
#  'Pricing-Homepage-Career tracks-Pricing': 1,
#  'Pricing-Upcoming courses-Other-Courses': 1,
#  'Pricing-Coupon-Checkout-Other': 1,
#  'Pricing-Resources center-Other-Sign up': 1,
#  'Pricing-Resources center-Homepage-Blog': 1,
#  'Pricing-Checkout-Homepage-Coupon': 1,
#  'Pricing-Career tracks-Log in-Checkout': 1,
#  'Pricing-Resources center-Courses-Pricing': 1,
#  'Pricing-Sign up-Resources center-Coupon': 1,
#  'Pricing-Career tracks-Sign up-Other': 1,
#  'Pricing-Checkout--Pricing': 1,
#  'Pricing-Other-Log in-Career tracks': 1,
#  'Pricing-Resources center-Courses-Pri': 1,
#  'Pricing-Sign up-Courses-Log in': 1,
#  'Pricing-Courses-Log in-Other': 1,
#  'Pricing-Career tracks-Pricing-Other': 1,
#  'Pricing-Other-Career tracks-Pricing': 1,
#  'Pricing-Sign up-Other-Log in': 1,
#  'Pricing-Resources center-Homepage-Sign up': 1,
#  'Pricing-Log in-Sign up-Coupon': 1,
#  'Pricing-Checkout-Courses-Coupon': 1,
#  'Pricing-Sign up-Coupon-Checkout': 1,
#  'Pricing-Courses-Career track certificate-Resources center': 1,
#  'Pricing-Career track certificate-Course certificate-Career tracks': 1,
#  'Pricing-Homepage-Career track certificate-Courses': 1,
#  'Pricing-Course certificate-Sign up-Homepage': 1,
#  'Pricing-Checkout-Career tracks-Checkout': 1,
#  'Pricing-Other-Pricing-Resources center': 1,
#  'Pricing-Checkout-Sign up-Checkout': 1,
#  'Pricing-Checkout-Pricing-Coupon': 1,
#  'Pricing-Homepage-Pricing-Course certificate': 1,
#  'Pricing-Course certificate-Pricing-Career tracks': 1,
#  'Pricing-Career tracks-Course certificate-Career track certificate': 1,
#  'Pricing-Other-Career track certificate-Courses': 1,
#  'Pricing-Course certificate-Other-Checkout': 1,
#  'Pricing-Sign up-Log in-Resources center': 1,
#  'Pricing-Career track certificate-Career tracks-Courses': 1,
#  'Pricing-Career track certificate-Success stories-Pricing': 1,
#  'Pricing-Success stories-Upcoming courses-Career tracks': 1,
#  'Pricing-Sign up-Career tracks-Success stories': 1,
#  'Pricing-Success stories-Log in-Checkout': 1,
#  'Pricing-Sign up-Pricing-Course certificate': 1,
#  'Pricing-Homepage-Career track certificate-Pricing': 1,
#  'Pricing-Courses-Homepage-Course certificate': 1,
#  'Pricing-Other-Pricing-Coupon': 1,
#  'Pricing-Career tracks-Courses-Cours': 1,
#  'Pricing-Homepage-Sign up-Log in': 1,
#  'Pricing-Homepage-Career tracks-Other': 1,
#  'Pricing-Homepage-Other-Checkout': 1,
#  'Pricing-Other-Courses-Pricing': 1,
#  'Pricing-Instructors-Courses-Homepage': 1,
#  'Pricing-Resources center-Sign up-Checkout': 1,
#  'Pricing-Course certificate-Pricing-Course certificate': 1,
#  'Pricing-Career track certificate-Sign up-Homepage': 1,
#  'Pricing-Log in-Success stories-Other': 1,
#  'Pricing-Homepage-Courses-Log in': 1,
#  'Pricing-Courses-Sign up-Career tracks': 1,
#  'Pricing-Career tracks-Upcoming courses-Courses': 1,
#  'Pricing-Career track certificate-Success stories-Other': 1,
#  'Pricing-Course certificate-Career track certificate-Sign up': 1,
#  'Pricing-Course certificate-Homepage-Course certificate': 1,
#  'Pricing-Course certificate-Other-Pricing': 1,
#  'Pricing-Courses-Homepage-Resources center': 1,
#  'Pricing-Success stories-Pricing-Upcoming courses': 1,
#  'Pricing-Resources center-Homepage-Resources center': 1,
#  'Pricing-Resources center-Other-Courses': 1,
#  'Pricing-Checkout-Career tracks-Courses': 1,
#  'Pricing-Other-Pricing-Course certificate': 1,
#  'Pricing-Sign up-Course certificate-Resources center': 1,
#  'Pricing-Course certificate-Resources center-Course certificate': 1,
#  'Pricing-Homepage-Courses-Career track certificate': 1,
#  'Pricing-Career track certificate-Career tracks-Success stories': 1,
#  'Pricing-Courses-Homepage-Other': 1,
#  'Pricing-Sign up-Homepage-Success stories': 1,
#  'Pricing-Log in-Career track certificate-Homepage': 1,
#  'Pricing-Sign up-Other-Sign up': 1,
#  'Pricing-Coupon-Log in-Career tracks': 1,
#  'Pricing-Homepage-Sign up-Career tracks': 1,
#  'Pricing-Coupon-Checkout-Log in': 1,
#  'Pricing-Career track certificate-Pricing-Success stories': 1,
#  'Pricing-Success stories-Pricing-Checkout': 1,
#  'Pricing-Career track certificate-Success stories-Career track certificate': 1,
#  'Pricing-Resources center-Courses-Checkout': 1,
#  'Pricing-Homepage-Log in-Sign up': 1,
#  'Pricing-Course certificate-Pricing-Homepage': 1,
#  'Pricing-Homepage-Courses-Upcoming courses': 1,
#  'Pricing-Course certificate-Resources center-Other': 1,
#  'Pricing-Other-Upcoming courses-Coupon': 1,
#  'Pricing-Checkout-Career track certificate-Sign up': 1,
#  'Pricing-Courses-Course certificate-Pricing': 1,
#  'Pricing-Coupon-Sign up-Log in': 1,
#  'Pricing-Resources center-Career track certificate-Courses': 1,
#  'Pricing-Checkout-Coupon-Other': 1,
#  'Pricing-Upcoming courses-Pricing-Homepage': 1,
#  'Pricing-Sign up-Other-Career tracks': 1}

# %%
df_user_journeys_last_3 = pd.read_csv('user_journey_23_01_to_23_03_last_3_sessions.csv')
df_user_journeys_last_3
# Out:
#       user_id subscription_type  \
# 0        1516            Yearly
# 1        3395            Yearly
# 2       10107            Yearly
# 3       11145           Monthly
# 4       12400           Monthly
# ...       ...               ...
# 1432   509060            Yearly
# 1433   509061            Yearly
# 1434   509085            Yearly
# 1435   509095            Yearly
# 1436   509096            Yearly
#
#                                            user_journey
# 0                                              Checkout
# 1                             Homepage-Pricing-Checkout
# 2                                              Checkout
# 3                                Log in-Homepage-Log in
# 4     Resources center-Career track certificate-Reso...
# ...                                                 ...
# 1432                                              Other
# 1433                                             Coupon
# 1434                                             Coupon
# 1435                                              Other
# 1436                                Coupon-Other-Coupon
#
# [1437 rows x 3 columns]

# %%
journey_length(df_user_journeys_last_3)
# Out:
# 4.4022268615170494

# %%
page_presence(df_user_journeys_last_3)
# Out:
# Checkout                    747
# Log in                      702
# Homepage                    579
# Coupon                      534
# Sign up                     331
# Other                       296
# Pricing                     204
# Courses                     189
# Career tracks               133
# Career track certificate     74
# Resources center             59
# Course certificate           42
# Upcoming courses             29
# Success stories              12
# Instructors                   9
# About us                      5
# Blog                          5
# Checkou                       1
# Career track certific         1
# C                             1
# Caree                         1
# Course certi                  1
# dtype: int64

# %%
page_sequences(df_user_journeys_last_3, run=4)
# Out:
# {'Log in-Homepage-Log in-Checkout': 80,
#  'Homepage-Log in-Homepage-Log in': 65,
#  'Log in-Homepage-Log in-Homepage': 52,
#  'Sign up-Homepage-Sign up-Checkout': 28,
#  'Sign up-Log in-Sign up-Log in': 19,
#  'Pricing-Checkout-Pricing-Checkout': 17,
#  'Log in-Sign up-Log in-Sign up': 17,
#  'Courses-Career tracks-Courses-Career tracks': 17,
#  'Log in-Homepage-Log in-Coupon': 16,
#  'Career tracks-Courses-Career tracks-Courses': 15,
#  'Log in-Homepage-Sign up-Log in': 15,
#  'Pricing-Checkout-Homepage-Pricing': 14,
#  'Checkout-Log in-Homepage-Log in': 14,
#  'Log in-Other-Log in-Checkout': 14,
#  'Homepage-Sign up-Log in-Checkout': 13,
#  'Sign up-Courses-Sign up-Checkout': 13,
#  'Sign up-Homepage-Sign up-Log in': 13,
#  'Sign up-Log in-Homepage-Sign up': 12,
#  'Checkout-Homepage-Pricing-Checkout': 12,
#  'Log in-Homepage-Log in-Other': 11,
#  'Homepage-Log in-Other-Log in': 11,
#  'Checkout-Homepage-Log in-Checkout': 11,
#  'Sign up-Courses-Homepage-Courses': 11,
#  'Homepage-Career tracks-Homepage-Career tracks': 10,
#  'Career tracks-Homepage-Career tracks-Homepage': 10,
#  'Homepage-Sign up-Homepage-Sign up': 10,
#  'Log in-Sign up-Log in-Checkout': 10,
#  'Log in-Sign up-Log in-Homepage': 10,
#  'Sign up-Courses-Sign up-Courses': 10,
#  'Courses-Sign up-Courses-Homepage': 10,
#  'Sign up-Log in-Homepage-Log in': 10,
#  'Homepage-Pricing-Checkout-Pricing': 9,
#  'Career tracks-Sign up-Career tracks-Sign up': 9,
#  'Courses-Sign up-Courses-Sign up': 9,
#  'Coupon-Log in-Homepage-Log in': 9,
#  'Sign up-Log in-Sign up-Checkout': 9,
#  'Checkout-Pricing-Checkout-Pricing': 9,
#  'Sign up-Career tracks-Homepage-Career tracks': 8,
#  'Courses-Homepage-Courses-Coupon': 8,
#  'Career tracks-Homepage-Career tracks-Coupon': 8,
#  'Sign up-Career tracks-Sign up-Career tracks': 8,
#  'Sign up-Homepage-Log in-Checkout': 8,
#  'Courses-Homepage-Courses-Homepage': 8,
#  'Homepage-Log in-Homepage-Sign up': 8,
#  'Homepage-Career tracks-Courses-Career tracks': 8,
#  'Career track certificate-Career tracks-Courses-Career tracks': 7,
#  'Career tracks-Career track certificate-Career tracks-Career track certificate': 7,
#  'Resources center-Other-Resources center-Other': 7,
#  'Other-Resources center-Other-Resources center': 7,
#  'Pricing-Sign up-Homepage-Pricing': 7,
#  'Career tracks-Sign up-Career tracks-Homepage': 7,
#  'Homepage-Pricing-Homepage-Pricing': 7,
#  'Log in-Sign up-Homepage-Sign up': 7,
#  'Sign up-Homepage-Pricing-Sign up': 7,
#  'Career tracks-Courses-Career tracks-Homepage': 7,
#  'Homepage-Pricing-Sign up-Pricing': 6,
#  'Other-Coupon-Other-Coupon': 6,
#  'Other-Log in-Homepage-Log in': 6,
#  'Sign up-Career tracks-Sign up-Checkout': 6,
#  'Homepage-Pricing-Log in-Checkout': 6,
#  'Courses-Career tracks-Courses-Homepage': 6,
#  'Homepage-Log in-Sign up-Log in': 6,
#  'Courses-Career track certificate-Courses-Career track certificate': 6,
#  'Career tracks-Homepage-Career tracks-Courses': 6,
#  'Career tracks-Homepage-Career tracks-Sign up': 6,
#  'Sign up-Homepage-Sign up-Homepage': 6,
#  'Career track certificate-Courses-Career track certificate-Courses': 6,
#  'Checkout-Pricing-Checkout-Homepage': 6,
#  'Pricing-Sign up-Pricing-Sign up': 5,
#  'Pricing-Courses-Pricing-Courses': 5,
#  'Homepage-Pricing-Log in-Coupon': 5,
#  'Career tracks-Pricing-Career tracks-Pricing': 5,
#  'Career track certificate-Homepage-Career track certificate-Sign up': 5,
#  'Homepage-Pricing-Checkout-Homepage': 5,
#  'Homepage-Pricing-Homepage-Log in': 5,
#  'Checkout-Pricing-Checkout-Coupon': 5,
#  'Sign up-Log in-Sign up-Courses': 5,
#  'Log in-Sign up-Courses-Sign up': 5,
#  'Log in-Homepage-Sign up-Homepage': 5,
#  'Homepage-Sign up-Log in-Sign up': 5,
#  'Career tracks-Sign up-Career tracks-Checkout': 5,
#  'Career tracks-Checkout-Pricing-Checkout': 5,
#  'Log in-Courses-Log in-Courses': 5,
#  'Homepage-Sign up-Log in-Homepage': 5,
#  'Log in-Other-Log in-Coupon': 5,
#  'Courses-Homepage-Courses-Sign up': 5,
#  'Career tracks-Courses-Career tracks-Pricing': 5,
#  'Courses-Career tracks-Homepage-Career tracks': 5,
#  'Log in-Other-Homepage-Log in': 4,
#  'Log in-Other-Log in-Homepage': 4,
#  'Checkout-Homepage-Pricing-Homepage': 4,
#  'Log in-Courses-Sign up-Log in': 4,
#  'Courses-Log in-Courses-Log in': 4,
#  'Pricing-Checkout-Log in-Checkout': 4,
#  'Homepage-Sign up-Homepage-Log in': 4,
#  'Resources center-Career track certificate-Resources center-Career track certificate': 4,
#  'Sign up-Homepage-Sign up-Coupon': 4,
#  'Homepage-Career tracks-Checkout-Pricing': 4,
#  'Homepage-Courses-Homepage-Courses': 4,
#  'Pricing-Homepage-Pricing-Coupon': 4,
#  'Homepage-Sign up-Homepage-Pricing': 4,
#  'Log in-Courses-Log in-Homepage': 4,
#  'Courses-Pricing-Courses-Sign up': 4,
#  'Courses-Sign up-Log in-Sign up': 4,
#  'Sign up-Homepage-Pricing-Checkout': 4,
#  'Log in-Homepage-Log in-Sign up': 4,
#  'Pricing-Homepage-Pricing-Log in': 4,
#  'Pricing-Log in-Pricing-Log in': 4,
#  'Courses-Pricing-Homepage-Pricing': 4,
#  'Courses-Homepage-Pricing-Courses': 4,
#  'Sign up-Log in-Sign up-Homepage': 4,
#  'Career tracks-Sign up-Courses-Sign up': 4,
#  'Career tracks-Courses-Homepage-Career tracks': 4,
#  'Homepage-Career tracks-Sign up-Coupon': 4,
#  'Sign up-Pricing-Sign up-Homepage': 4,
#  'Log in-Pricing-Log in-Checkout': 4,
#  'Pricing-Career tracks-Sign up-Career tracks': 4,
#  'Career tracks-Upcoming courses-Career tracks-Courses': 4,
#  'Career tracks-Courses-Career tracks-Career track certificate': 4,
#  'Checkout-Homepage-Sign up-Log in': 3,
#  'Sign up-Pricing-Sign up-Pricing': 3,
#  'Career tracks-Homepage-Sign up-Homepage': 3,
#  'Career track certificate-Career tracks-Career track certificate-Career tracks': 3,
#  'Courses-Pricing-Courses-Pricing': 3,
#  'Pricing-Homepage-Log in-Checkout': 3,
#  'Pricing-Checkout-Courses-Pricing': 3,
#  'Pricing-Courses-Log in-Checkout': 3,
#  'Coupon-Other-Coupon-Other': 3,
#  'Pricing-Checkout-Pricing-Sign up': 3,
#  'Resources center-Other-Resources center-Homepage': 3,
#  'Checkout-Homepage-Pricing-Log in': 3,
#  'Pricing-Career tracks-Pricing-Career tracks': 3,
#  'Courses-Sign up-Pricing-Sign up': 3,
#  'Log in-Courses-Log in-Checkout': 3,
#  'Log in-Homepage-Log in-Courses': 3,
#  'Homepage-Pricing-Checkout-Log in': 3,
#  'Homepage-Pricing-Sign up-Log in': 3,
#  'Pricing-Checkout-Log in-Homepage': 3,
#  'Pricing-Courses-Homepage-Courses': 3,
#  'Courses-Homepage-Courses-Career track certificate': 3,
#  'Career track certificate-Resources center-Career track certificate-Courses': 3,
#  'Resources center-Career track certificate-Courses-Career track certificate': 3,
#  'Sign up-Log in-Courses-Sign up': 3,
#  'Homepage-Sign up-Homepage-Career tracks': 3,
#  'Career tracks-Log in-Sign up-Log in': 3,
#  'Career tracks-Upcoming courses-Courses-Career tracks': 3,
#  'Career tracks-Courses-Career tracks-Sign up': 3,
#  'Other-Homepage-Log in-Checkout': 3,
#  'Log in-Career tracks-Log in-Checkout': 3,
#  'Homepage-Sign up-Log in-Coupon': 3,
#  'Sign up-Courses-Sign up-Homepage': 3,
#  'Courses-Sign up-Homepage-Log in': 3,
#  'Homepage-Pricing-Log in-Homepage': 3,
#  'Pricing-Log in-Homepage-Log in': 3,
#  'Homepage-Career track certificate-Sign up-Career track certificate': 3,
#  'Career track certificate-Sign up-Career track certificate-Sign up': 3,
#  'Sign up-Career track certificate-Sign up-Career track certificate': 3,
#  'Career track certificate-Sign up-Homepage-Career track certificate': 3,
#  'Checkout-Pricing-Checkout-Career tracks': 3,
#  'Pricing-Checkout-Career tracks-Pricing': 3,
#  'Career tracks-Courses-Career tracks-Log in': 3,
#  'Courses-Career tracks-Log in-Courses': 3,
#  'Courses-Homepage-Sign up-Courses': 3,
#  'Courses-Homepage-Courses-Pricing': 3,
#  'Pricing-Homepage-Pricing-Checkout': 3,
#  'Career tracks-Courses-Homepage-Courses': 3,
#  'Courses-Sign up-Courses-Log in': 3,
#  'Sign up-Pricing-Sign up-Checkout': 3,
#  'Other-Log in-Sign up-Log in': 3,
#  'Other-Career tracks-Homepage-Career tracks': 3,
#  'Career track certificate-Homepage-Career track certificate-Courses': 3,
#  'Checkout-Log in-Sign up-Log in': 3,
#  'Homepage-Pricing-Career track certificate-Sign up': 3,
#  'Pricing-Career track certificate-Sign up-Career track certificate': 3,
#  'Checkout-Homepage-Log in-Homepage': 3,
#  'Career track certificate-Sign up-Career track certificate-Homepage': 3,
#  'Homepage-Pricing-Log in-Pricing': 3,
#  'Homepage-Log in-Checkout-Log in': 3,
#  'Courses-Log in-Homepage-Log in': 3,
#  'Resources center-Other-Resources center-Log in': 3,
#  'Log in-Checkout-Homepage-Log in': 3,
#  'Homepage-Courses-Homepage-Pricing': 3,
#  'Sign up-Career tracks-Sign up-Log in': 3,
#  'Coupon-Sign up-Homepage-Sign up': 3,
#  'Sign up-Pricing-Sign up-Coupon': 3,
#  'Sign up-Courses-Sign up-Career tracks': 3,
#  'Courses-Career tracks-Homepage-Courses': 3,
#  'Courses-Homepage-Career tracks-Courses': 3,
#  'Career track certificate-Courses-Career track certificate-Homepage': 3,
#  'Courses-Homepage-Career tracks-Homepage': 3,
#  'Homepage-Career tracks-Sign up-Log in': 3,
#  'Career tracks-Sign up-Log in-Coupon': 3,
#  'Sign up-Homepage-Career tracks-Sign up': 3,
#  'Courses-Sign up-Career tracks-Courses': 3,
#  'Course certificate-Career track certificate-Course certificate-Career track certificate': 3,
#  'Sign up-Courses-Career tracks-Courses': 3,
#  'Upcoming courses-Career tracks-Courses-Career tracks': 3,
#  'Courses-Homepage-Courses-Checkout': 3,
#  'Courses-Career tracks-Career track certificate-Career tracks': 3,
#  'Coupon-Checkout-Pricing-Checkout': 3,
#  'Pricing-Homepage-Pricing-Homepage': 3,
#  'Courses-Upcoming courses-Courses-Pricing': 3,
#  'Pricing-Career tracks-Pricing-Checkout': 3,
#  'Career tracks-Sign up-Log in-Checkout': 3,
#  'Sign up-Career tracks-Career track certificate-Career tracks': 3,
#  'Sign up-Other-Sign up-Checkout': 3,
#  'Homepage-Career tracks-Sign up-Checkout': 3,
#  'Log in-Sign up-Homepage-Pricing': 3,
#  'Homepage-Career tracks-Homepage-Courses': 3,
#  'Courses-Homepage-Courses-Career tracks': 3,
#  'Career track certificate-Homepage-Log in-Homepage': 2,
#  'Homepage-Career tracks-Homepage-Pricing': 2,
#  'Career tracks-Homepage-Pricing-Sign up': 2,
#  'Homepage-Career tracks-Homepage-Sign up': 2,
#  'Homepage-Career track certificate-Career tracks-Courses': 2,
#  'Courses-Career tracks-Courses-Career track certificate': 2,
#  'Career track certificate-Career tracks-Career track certificate-Coupon': 2,
#  'Homepage-Pricing-Checkout-Courses': 2,
#  'Courses-Pricing-Courses-Log in': 2,
#  'Checkout-Pricing-Sign up-Checkout': 2,
#  'Other-Resources center-Homepage-Log in': 2,
#  'Other-Homepage-Log in-Other': 2,
#  'Homepage-Log in-Other-Checkout': 2,
#  'Sign up-Checkout-Homepage-Log in': 2,
#  'Other-Pricing-Other-Pricing': 2,
#  'Sign up-Homepage-Pricing-Other': 2,
#  'Homepage-Log in-Other-Coupon': 2,
#  'Log in-Pricing-Log in-Other': 2,
#  'Log in-Sign up-Log in-Career track certificate': 2,
#  'Sign up-Career track certificate-Homepage-Career track certificate': 2,
#  'Homepage-Career track certificate-Sign up-Log in': 2,
#  'Career track certificate-Sign up-Log in-Checkout': 2,
#  'Sign up-Log in-Checkout-Coupon': 2,
#  'Homepage-Pricing-Sign up-Checkout': 2,
#  'Courses-Sign up-Log in-Coupon': 2,
#  'Homepage-Log in-Checkout-Coupon': 2,
#  'Coupon-Homepage-Log in-Other': 2,
#  'Homepage-Log in-Courses-Log in': 2,
#  'Career track certificate-Log in-Homepage-Log in': 2,
#  'Resources center-Other-Homepage-Log in': 2,
#  'Checkout-Pricing-Checkout-Courses': 2,
#  'Homepage-Pricing-Checkout-Coupon': 2,
#  'Courses-Upcoming courses-Courses-Upcoming courses': 2,
#  'Career track certificate-Success stories-Other-Success stories': 2,
#  'Courses-Upcoming courses-Courses-Resources center': 2,
#  'Other-Resources center-Career track certificate-Resources center': 2,
#  'Career track certificate-Courses-Career track certificate-Checkout': 2,
#  'Sign up-Homepage-Career tracks-Homepage': 2,
#  'Homepage-Career tracks-Log in-Sign up': 2,
#  'Upcoming courses-Career tracks-Upcoming courses-Courses': 2,
#  'Upcoming courses-Courses-Career tracks-Courses': 2,
#  'Homepage-Courses-Sign up-Courses': 2,
#  'Courses-Homepage-Courses-Log in': 2,
#  'Other-Homepage-Log in-Homepage': 2,
#  'Career tracks-Pricing-Career tracks-Career track certificate': 2,
#  'Sign up-Career track certificate-Log in-Checkout': 2,
#  'Course certificate-Career track certificate-Career tracks-Courses': 2,
#  'Homepage-Pricing-Courses-Homepage': 2,
#  'Homepage-Courses-Homepage-Career tracks': 2,
#  'Checkout-Career tracks-Pricing-Career tracks': 2,
#  'Career tracks-Pricing-Career tracks-Courses': 2,
#  'Career tracks-Log in-Courses-Log in': 2,
#  'Course certificate-Homepage-Course certificate-Log in': 2,
#  'Pricing-Sign up-Log in-Homepage': 2,
#  'Log in-Homepage-Pricing-Checkout': 2,
#  'Sign up-Career tracks-Courses-Career tracks': 2,
#  'Log in-Sign up-Log in-Coupon': 2,
#  'Courses-Homepage-Log in-Checkout': 2,
#  'Checkout-Log in-Other-Log in': 2,
#  'Homepage-Courses-Homepage-Sign up': 2,
#  'Homepage-Courses-Pricing-Courses': 2,
#  'Pricing-Courses-Pricing-Other': 2,
#  'Courses-Pricing-Other-Pricing': 2,
#  'Pricing-Other-Pricing-Log in': 2,
#  'Homepage-Log in-Other-Homepage': 2,
#  'Pricing-Log in-Homepage-Pricing': 2,
#  'Coupon-Courses-Homepage-Courses': 2,
#  'Log in-Homepage-Pricing-Log in': 2,
#  'Homepage-Pricing-Log in-Career track certificate': 2,
#  'Pricing-Log in-Pricing-Homepage': 2,
#  'Log in-Pricing-Homepage-Pricing': 2,
#  'Checkout-Pricing-Sign up-Log in': 2,
#  'Sign up-Homepage-Pricing-Coupon': 2,
#  'Courses-Pricing-Courses-Homepage': 2,
#  'Pricing-Courses-Homepage-Pricing': 2,
#  'Pricing-Resources center-Pricing-Courses': 2,
#  'Resources center-Pricing-Courses-Pricing': 2,
#  'Sign up-Courses-Log in-Checkout': 2,
#  'Homepage-Log in-Pricing-Log in': 2,
#  'Log in-Other-Log in-Sign up': 2,
#  'Homepage-Pricing-Sign up-Homepage': 2,
#  'Pricing-Sign up-Homepage-Sign up': 2,
#  'Career tracks-Other-Career tracks-Homepage': 2,
#  'Career tracks-Homepage-Career tracks-Log in': 2,
#  'Career track certificate-Courses-Sign up-Courses': 2,
#  'Sign up-Courses-Pricing-Courses': 2,
#  'Log in-Homepage-Career tracks-Homepage': 2,
#  'Sign up-Career track certificate-Homepage-Pricing': 2,
#  'Career track certificate-Homepage-Pricing-Checkout': 2,
#  'Career tracks-Homepage-Log in-Checkout': 2,
#  'Log in-Checkout-Pricing-Checkout': 2,
#  'Courses-Log in-Homepage-Courses': 2,
#  'Homepage-Courses-Pricing-Homepage': 2,
#  'Homepage-Courses-Homepage-Coupon': 2,
#  'Homepage-Log in-Checkout-Homepage': 2,
#  'Courses-Career track certificate-Upcoming courses-Courses': 2,
#  'Log in-Career tracks-Sign up-Log in': 2,
#  'Homepage-Courses-Sign up-Checkout': 2,
#  'Coupon-Homepage-Log in-Coupon': 2,
#  'Log in-Sign up-Log in-Courses': 2,
#  'Homepage-Courses-Homepage-Course certificate': 2,
#  'Sign up-Log in-Courses-Log in': 2,
#  'Courses-Log in-Courses-Sign up': 2,
#  'Homepage-Log in-Homepage-Career track certificate': 2,
#  'Homepage-Pricing-Courses-Pricing': 2,
#  'Career track certificate-Resources center-Career track certificate-Resources center': 2,
#  'Course certificate-Courses-Sign up-Courses': 2,
#  'Career tracks-Career track certificate-Career tracks-Sign up': 2,
#  'Career track certificate-Career tracks-Sign up-Career tracks': 2,
#  'Career tracks-Homepage-Pricing-Homepage': 2,
#  'Career track certificate-Sign up-Career track certificate-Career tracks': 2,
#  'Career tracks-Pricing-Homepage-Career tracks': 2,
#  'Homepage-Career tracks-Courses-Coupon': 2,
#  'Homepage-Courses-Other-Course certificate': 2,
#  'Courses-Other-Course certificate-Courses': 2,
#  'Other-Course certificate-Courses-Sign up': 2,
#  'Homepage-Career tracks-Sign up-Homepage': 2,
#  'Career tracks-Sign up-Homepage-Career tracks': 2,
#  'Courses-Career tracks-Courses-Course certificate': 2,
#  'Career track certificate-Career tracks-Career track certificate-Courses': 2,
#  'Career tracks-Career track certificate-Courses-Career track certificate': 2,
#  'Courses-Career track certificate-Courses-Pricing': 2,
#  'Courses-Sign up-Homepage-Sign up': 2,
#  'Career track certificate-Course certificate-Career track certificate-Course certificate': 2,
#  'Homepage-Log in-Pricing-Checkout': 2,
#  'Sign up-Other-Sign up-Log in': 2,
#  'Other-Sign up-Log in-Coupon': 2,
#  'Log in-Pricing-Log in-Pricing': 2,
#  'Courses-Sign up-Courses-Career tracks': 2,
#  'Courses-Career tracks-Courses-Upcoming courses': 2,
#  'Career tracks-Courses-Upcoming courses-Courses': 2,
#  'Courses-Pricing-Courses-Coupon': 2,
#  'Career tracks-Pricing-Career tracks-Homepage': 2,
#  'Pricing-Career tracks-Homepage-Pricing': 2,
#  'Career tracks-Homepage-Courses-Career tracks': 2,
#  'Homepage-Courses-Career tracks-Coupon': 2,
#  'Upcoming courses-Courses-Sign up-Courses': 2,
#  'Career track certificate-Homepage-Career track certificate-Coupon': 2,
#  'Checkout-Pricing-Checkout-Log in': 2,
#  'Pricing-Homepage-Career tracks-Coupon': 2,
#  'Upcoming courses-Courses-Pricing-Homepage': 2,
#  'Courses-Career track certificate-Career tracks-Upcoming courses': 2,
#  'Career track certificate-Career tracks-Upcoming courses-Career tracks': 2,
#  'Career tracks-Courses-Career tracks-Coupon': 2,
#  'Courses-Career tracks-Sign up-Courses': 2,
#  'Career tracks-Sign up-Courses-Career tracks': 2,
#  'Course certificate-Courses-Career tracks-Courses': 2,
#  'Sign up-Homepage-Sign up-Other': 2,
#  'Homepage-Courses-Career tracks-Sign up': 2,
#  'Pricing-Courses-Career tracks-Courses': 2,
#  'Courses-Career tracks-Pricing-Career tracks': 2,
#  'Courses-Career tracks-Courses-Coupon': 2,
#  'Other-Blog-Other-Blog': 2,
#  'Blog-Other-Blog-Other': 2,
#  'Homepage-Sign up-Coupon-Checkout': 2,
#  'Career tracks-Courses-Career tracks-Checkout': 2,
#  'Courses-Sign up-Homepage-Courses': 2,
#  'Course certificate-Resources center-Course certificate-Resources center': 2,
#  'Resources center-Course certificate-Resources center-Course certificate': 2,
#  'Resources center-Course certificate-Resources center-Pricing': 2,
#  'Course certificate-Resources center-Pricing-Resources center': 2,
#  'Sign up-Log in-Career tracks-Sign up': 2,
#  'Courses-Pricing-Courses-Career tracks': 2,
#  'Courses-Homepage-Pricing-Coupon': 2,
#  'Resources center-Courses-Homepage-Pricing': 2,
#  'Pricing-Sign up-Log in-Checkout': 2,
#  'Homepage-Course certificate-Sign up-Course certificate': 2,
#  'Course certificate-Sign up-Course certificate-Sign up': 2,
#  'Homepage-Career track certificate-Homepage-Career track certificate': 2,
#  'Career tracks-Log in-Career tracks-Log in': 2,
#  'Homepage-Courses-Checkout-Homepage': 2,
#  'Courses-Checkout-Homepage-Pricing': 2,
#  'Courses-Homepage-Pricing-Checkout': 2,
#  'Log in-Success stories-Other-Success stories': 2,
#  'Courses-Course certificate-Courses-Course certificate': 2,
#  'Career tracks-Pricing-Career tracks-Sign up': 2,
#  'Homepage-Sign up-Courses-Sign up': 2,
#  'Career track certificate-Career tracks-Career track certificate-Homepage': 2,
#  'Pricing-Resources center-Pricing-Resources center': 2,
#  'Resources center-Pricing-Resources center-Pricing': 2,
#  'Homepage-Courses-Sign up-Homepage': 2,
#  'Homepage-Courses-Sign up-Log in': 2,
#  'Courses-Pricing-Homepage-Courses': 2,
#  'Pricing-Homepage-Courses-Pricing': 2,
#  'Sign up-Pricing-Log in-Checkout': 2,
#  'Career track certificate-Homepage-Sign up-Career track certificate': 2,
#  'Log in-Homepage-Sign up-Coupon': 2,
#  'Career tracks-Course certificate-Career tracks-Course certificate': 2,
#  'Course certificate-Career tracks-Course certificate-Courses': 2,
#  'Course certificate-Courses-Course certificate-Courses': 2,
#  'Sign up-Checkout-Log in-Homepage': 2,
#  'Career track certificate-Pricing-Career track certificate-Career tracks': 2,
#  'Courses-Resources center-Pricing-Courses': 2,
#  'Pricing-Resources center-Other-Resources center': 2,
#  'Career tracks-Homepage-Courses-Sign up': 2,
#  'Courses-Sign up-Career tracks-Sign up': 2,
#  'Homepage-Sign up-Homepage-Courses': 2,
#  'Sign up-Homepage-Courses-Homepage': 2,
#  'Courses-Sign up-Log in-Checkout': 2,
#  'Success stories-Other-Success stories-Checkout': 2,
#  'Sign up-Career track certificate-Career tracks-Career track certificate': 2,
#  'Courses-Course certificate-Courses-Homepage': 2,
#  'Course certificate-Courses-Homepage-Courses': 2,
#  'Other-Checkout-Pricing-Checkout': 2,
#  'Homepage-Courses-Career tracks-Courses': 2,
#  'Sign up-Career track certificate-Sign up-Checkout': 2,
#  'Pricing-Sign up-Other-Pricing': 2,
#  'Log in-Homepage-Sign up-Checkout': 2,
#  'Pricing-Sign up-Pricing-Resources center': 2,
#  'Resources center-Career track certificate-Resources center-Other': 1,
#  'Career track certificate-Resources center-Other-Career track certificate': 1,
#  'Resources center-Other-Career track certificate-Homepage': 1,
#  'Other-Career track certificate-Homepage-Log in': 1,
#  'Homepage-Log in-Homepage-Instructors': 1,
#  'Log in-Homepage-Instructors-Homepage': 1,
#  'Homepage-Instructors-Homepage-Checkout': 1,
#  'Sign up-Pricing-Sign up-Career tracks': 1,
#  'Pricing-Sign up-Career tracks-Homepage': 1,
#  'Career tracks-Courses-Career track certificate-Career tracks': 1,
#  'Courses-Career track certificate-Career tracks-Career track certificate': 1,
#  'Courses-Pricing-Courses-Career track certificate': 1,
#  'Pricing-Courses-Career track certificate-Pricing': 1,
#  'Courses-Career track certificate-Pricing-Homepage': 1,
#  'Career track certificate-Pricing-Homepage-Log in': 1,
#  'Checkout-Courses-Pricing-Courses': 1,
#  'Coupon-Pricing-Checkout-Pricing': 1,
#  'Homepage-Sign up-Checkout-Homepage': 1,
#  'Pricing-Instructors-Pricing-Success stories': 1,
#  'Instructors-Pricing-Success stories-Pricing': 1,
#  'Pricing-Success stories-Pricing-Success stories': 1,
#  'Success stories-Pricing-Success stories-Homepage': 1,
#  'Pricing-Success stories-Homepage-Success stories': 1,
#  'Success stories-Homepage-Success stories-Coupon': 1,
#  'Checkout-Pricing-Checkout-Other': 1,
#  'Pricing-Checkout-Other-Pricing': 1,
#  'Checkout-Other-Pricing-Other': 1,
#  'Pricing-Other-Pricing-Career tracks': 1,
#  'Other-Pricing-Career tracks-Pricing': 1,
#  'Career tracks-Pricing-Career tracks-Checkout': 1,
#  'Pricing-Other-Log in-Pricing': 1,
#  'Other-Log in-Pricing-Sign up': 1,
#  'Log in-Pricing-Sign up-Homepage': 1,
#  'Homepage-Pricing-Other-Courses': 1,
#  'Pricing-Other-Courses-Sign up': 1,
#  'Other-Courses-Sign up-Pricing': 1,
#  'Sign up-Pricing-Sign up-Log in': 1,
#  'Pricing-Sign up-Log in-Coupon': 1,
#  'Sign up-Log in-Coupon-Other': 1,
#  'Sign up-Log in-Career track certificate-Log in': 1,
#  'Log in-Career track certificate-Log in-Sign up': 1,
#  'Career track certificate-Log in-Sign up-Career track certificate': 1,
#  'Log in-Sign up-Career track certificate-Homepage': 1,
#  'Homepage-Career track certificate-Sign up-Career tracks': 1,
#  'Career track certificate-Sign up-Career tracks-Sign up': 1,
#  'Log in-Resources center-Other-Resources center': 1,
#  'Resources center-Other-Resources center-Checkout': 1,
#  'Checkout-Log in-Courses-Sign up': 1,
#  'Pricing-Homepage-Pricing-Sign up': 1,
#  'Pricing-Sign up-Log in-Sign up': 1,
#  'Other-Blog-Log in-Checkout': 1,
#  'Career track certificate-Homepage-Course certificate-Career track certificate': 1,
#  'Homepage-Course certificate-Career track certificate-Log in': 1,
#  'Course certificate-Career track certificate-Log in-Homepage': 1,
#  'Homepage-Pricing-Career tracks-Log in': 1,
#  'Pricing-Career tracks-Log in-Homepage': 1,
#  'Career tracks-Log in-Homepage-Log in': 1,
#  'Other-Career track certificate-Sign up-Log in': 1,
#  'Pricing-Checkout-Courses-Career tracks': 1,
#  'Checkout-Courses-Career tracks-Other': 1,
#  'Courses-Career tracks-Other-Resources center': 1,
#  'Career tracks-Other-Resources center-Career tracks': 1,
#  'Other-Resources center-Career tracks-Resources center': 1,
#  'Resources center-Career tracks-Resources center-Other': 1,
#  'Career tracks-Resources center-Other-Resources center': 1,
#  'Other-Resources center-Other-Career tracks': 1,
#  'Resources center-Other-Career tracks-Resources center': 1,
#  'Other-Career tracks-Resources center-Other': 1,
#  'Career tracks-Resources center-Other-Career tracks': 1,
#  'Career tracks-Resources center-Other-Coupon': 1,
#  'Checkout-Sign up-Courses-Sign up': 1,
#  'Sign up-Courses-Sign up-Log in': 1,
#  'Homepage-Log in-Coupon-Checkout': 1,
#  'Other-Homepage-Pricing-Checkout': 1,
#  'Upcoming courses-Courses-Upcoming courses-Pricing': 1,
#  'Courses-Upcoming courses-Pricing-Courses': 1,
#  'Upcoming courses-Pricing-Courses-Homepage': 1,
#  'Homepage-Courses-Career track certificate-Success stories': 1,
#  'Courses-Career track certificate-Success stories-Career track certificate': 1,
#  'Career track certificate-Success stories-Career track certificate-Success stories': 1,
#  'Success stories-Career track certificate-Success stories-Other': 1,
#  'Success stories-Other-Success stories-Upcoming courses': 1,
#  'Other-Success stories-Upcoming courses-Success stories': 1,
#  'Success stories-Upcoming courses-Success stories-Homepage': 1,
#  'Upcoming courses-Success stories-Homepage-Log in': 1,
#  'Success stories-Homepage-Log in-Upcoming courses': 1,
#  'Homepage-Log in-Upcoming courses-Resources center': 1,
#  'Log in-Upcoming courses-Resources center-Courses': 1,
#  'Upcoming courses-Resources center-Courses-Upcoming courses': 1,
#  'Resources center-Courses-Upcoming courses-Courses': 1,
#  'Upcoming courses-Courses-Resources center-About us': 1,
#  'Courses-Resources center-About us-Courses': 1,
#  'Resources center-About us-Courses-About us': 1,
#  'About us-Courses-About us-Other': 1,
#  'Courses-About us-Other-Resources center': 1,
#  'About us-Other-Resources center-Career track certificate': 1,
#  'Homepage-Log in-Resources center-Other': 1,
#  'Homepage-Courses-Career tracks-Career track certificate': 1,
#  'Courses-Career tracks-Career track certificate-Sign up': 1,
#  'Career tracks-Career track certificate-Sign up-Log in': 1,
#  'Career track certificate-Sign up-Log in-Courses': 1,
#  'Log in-Courses-Sign up-Other': 1,
#  'Courses-Sign up-Other-Courses': 1,
#  'Sign up-Other-Courses-Course certificate': 1,
#  'Other-Courses-Course certificate-Other': 1,
#  'Courses-Course certificate-Other-Career track certificate': 1,
#  'Course certificate-Other-Career track certificate-Course certificate': 1,
#  'Other-Career track certificate-Course certificate-Coupon': 1,
#  'Homepage-Career tracks-Homepage-Coupon': 1,
#  'Coupon-Sign up-Log in-Sign up': 1,
#  'Log in-Upcoming courses-Career tracks-Upcoming courses': 1,
#  'Courses-Career tracks-Sign up-Log in': 1,
#  'Career tracks-Sign up-Log in-Other': 1,
#  'Log in-Career track certificate-Log in-Homepage': 1,
#  'Other-Homepage-Resources center-Other': 1,
#  'Homepage-Resources center-Other-Homepage': 1,
#  'Homepage-Courses-Log in-Checkout': 1,
#  'Log in-Coupon-Homepage-Sign up': 1,
#  'Coupon-Homepage-Sign up-Log in': 1,
#  'Pricing-Career tracks-Career track certificate-Sign up': 1,
#  'Career tracks-Career track certificate-Sign up-Career track certificate': 1,
#  'Career track certificate-Sign up-Career track certificate-Log in': 1,
#  'Sign up-Career track certificate-Sign up-Homepage': 1,
#  'Sign up-Homepage-Career track certificate-Checkout': 1,
#  'Other-Course certificate-Career track certificate-Career tracks': 1,
#  'Career track certificate-Career tracks-Courses-Course certificate': 1,
#  'Career tracks-Courses-Course certificate-Career track certificate': 1,
#  'Courses-Course certificate-Career track certificate-Coupon': 1,
#  'Course certificate-Career track certificate-Coupon-Checkout': 1,
#  'Courses-Homepage-Career tracks-Checkout': 1,
#  'Pricing-Career tracks-Courses-Career tracks': 1,
#  'Checkout-Homepage-Career tracks-Courses': 1,
#  'Log in-Courses-Log in-Course certificate': 1,
#  'Courses-Log in-Course certificate-Homepage': 1,
#  'Log in-Course certificate-Homepage-Course certificate': 1,
#  'Course certificate-Homepage-Course certificate-Homepage': 1,
#  'Homepage-Course certificate-Homepage-Course certificate': 1,
#  'Homepage-Course certificate-Log in-Course certificate': 1,
#  'Course certificate-Log in-Course certificate-Log in': 1,
#  'Log in-Course certificate-Log in-Checkout': 1,
#  'Homepage-Resources center-Other-Resources center': 1,
#  'Sign up-Log in-Homepage-Pricing': 1,
#  'Career tracks-Sign up-Career tracks-Courses': 1,
#  'Courses-Career tracks-Log in-Sign up': 1,
#  'Sign up-Homepage-Log in-Homepage': 1,
#  'Log in-Resources center-Pricing-Coupon': 1,
#  'Career track certificate-Course certificate-Career track certificate-Career tracks': 1,
#  'Course certificate-Career track certificate-Career tracks-Course certificate': 1,
#  'Career track certificate-Career tracks-Course certificate-Career track certificate': 1,
#  'Career tracks-Course certificate-Career track certificate-Career tracks': 1,
#  'Career track certificate-Career tracks-Courses-Career track certificate': 1,
#  'Career tracks-Courses-Career track certificate-Homepage': 1,
#  'Courses-Career track certificate-Homepage-Courses': 1,
#  'Career track certificate-Homepage-Courses-Homepage': 1,
#  'Homepage-Courses-Homepage-Log in': 1,
#  'Coupon-Homepage-Courses-Coupon': 1,
#  'Courses-Other-Courses-Homepage': 1,
#  'Other-Courses-Homepage-Courses': 1,
#  'Homepage-Sign up-Courses-Homepage': 1,
#  'Other-Pricing-Log in-Homepage': 1,
#  'Log in-Other-Homepage-Checkout': 1,
#  'Coupon-Log in-Other-Log in': 1,
#  'Sign up-Log in-Sign up-Other': 1,
#  'Log in-Sign up-Other-Log in': 1,
#  'Sign up-Other-Log in-Checkout': 1,
#  'Other-Resources center-Other-Sign up': 1,
#  'Resources center-Other-Sign up-Coupon': 1,
#  'Log in-Homepage-Pricing-Homepage': 1,
#  'Coupon-Resources center-Other-Log in': 1,
#  'Coupon-Other-Coupon-Courses': 1,
#  'Other-Coupon-Courses-Homepage': 1,
#  'Pricing-Log in-Career track certificate-Success stories': 1,
#  'Log in-Career track certificate-Success stories-Career track certificate': 1,
#  'Checkout-Courses-Log in-Courses': 1,
#  'Courses-Log in-Courses-Career tracks': 1,
#  'Log in-Courses-Career tracks-Log in': 1,
#  'Career tracks-Log in-Courses-Career tracks': 1,
#  'Courses-Career tracks-Log in-Career tracks': 1,
#  'Career tracks-Log in-Career tracks-Courses': 1,
#  'Log in-Career tracks-Courses-Career tracks': 1,
#  'Coupon-Pricing-Log in-Pricing': 1,
#  'Other-Pricing-Checkout-Pricing': 1,
#  'Courses-Homepage-Pricing-Log in': 1,
#  'Homepage-Sign up-Log in-Resources center': 1,
#  'Sign up-Log in-Resources center-Other': 1,
#  'Homepage-Log in-Courses-Career tracks': 1,
#  'Log in-Courses-Career tracks-Courses': 1,
#  'Courses-Log in-Homepage-Career tracks': 1,
#  'Log in-Homepage-Career tracks-Courses': 1,
#  'Pricing-Courses-Sign up-Log in': 1,
#  'Log in-Pricing-Log in-Homepage': 1,
#  'Other-Resources center-Other-Log in': 1,
#  'Resources center-Other-Log in-Resources center': 1,
#  'Other-Log in-Resources center-Other': 1,
#  'Log in-Resources center-Other-Log in': 1,
#  'Resources center-Other-Log in-Checkout': 1,
#  'Sign up-Log in-Sign up-Pricing': 1,
#  'Log in-Sign up-Pricing-Sign up': 1,
#  'Pricing-Sign up-Pricing-Checkout': 1,
#  'Sign up-Pricing-Checkout-Homepage': 1,
#  'Checkout-Homepage-Pricing-Sign up': 1,
#  'Courses-Career track certificate-Checkout-Homepage': 1,
#  'Career track certificate-Checkout-Homepage-Pricing': 1,
#  'Checkout-Courses-Pricing-Sign up': 1,
#  'Courses-Pricing-Sign up-Homepage': 1,
#  'Career tracks-Courses-Other-Career tracks': 1,
#  'Courses-Other-Career tracks-Other': 1,
#  'Other-Career tracks-Other-Career tracks': 1,
#  'Homepage-Career tracks-Log in-Checkout': 1,
#  'Resources center-Other-Homepage-Pricing': 1,
#  'Other-Homepage-Pricing-Coupon': 1,
#  'Pricing-Sign up-Pricing-Homepage': 1,
#  'Sign up-Pricing-Homepage-Pricing': 1,
#  'Pricing-Log in-Career track certificate-Pricing': 1,
#  'Log in-Career track certificate-Pricing-Career track certificate': 1,
#  'Career track certificate-Pricing-Career track certificate-Homepage': 1,
#  'Pricing-Career track certificate-Homepage-Career track certificate': 1,
#  'Homepage-Career track certificate-Courses-Sign up': 1,
#  'Courses-Sign up-Courses-Pricing': 1,
#  'Pricing-Courses-Sign up-Coupon': 1,
#  'Homepage-Pricing-Log in-Resources center': 1,
#  'Pricing-Log in-Resources center-Log in': 1,
#  'Log in-Resources center-Log in-Coupon': 1,
#  'Career track certificate-Sign up-Career track certificate-Pricing': 1,
#  'Sign up-Career track certificate-Pricing-Career track certificate': 1,
#  'Career track certificate-Pricing-Career track certificate-Coupon': 1,
#  'Homepage-Course certificate-Log in-Checkout': 1,
#  'Log in-Career tracks-Homepage-Log in': 1,
#  'Coupon-Homepage-Career tracks-Checkout': 1,
#  'Log in-Coupon-Log in-Homepage': 1,
#  'Checkout-Instructors-About us-Other': 1,
#  'Pricing-Courses-Log in-Homepage': 1,
#  'Checkout-Other-Sign up-Log in': 1,
#  'Other-Sign up-Log in-Checkout': 1,
#  'Other-Log in-Checkout-Pricing': 1,
#  'Log in-Homepage-Course certificate-Coupon': 1,
#  'Log in-Courses-Log in-Coupon': 1,
#  'Log in-Other-Log in-Courses': 1,
#  'Other-Log in-Courses-Log in': 1,
#  'Log in-Homepage-Courses-Pricing': 1,
#  'Homepage-Log in-Homepage-Courses': 1,
#  'Log in-Homepage-Courses-Homepage': 1,
#  'Checkout-Course certificate-Homepage-Course certificate': 1,
#  'Course certificate-Homepage-Course certificate-Checkout': 1,
#  'Homepage-Log in-Sign up-Homepage': 1,
#  'Homepage-Pricing-Homepage-Courses': 1,
#  'Pricing-Homepage-Courses-Checkout': 1,
#  'Log in-Other-Log in-Other': 1,
#  'Other-Log in-Other-Log in': 1,
#  'Checkout-Checkou-Checkout-Homepage': 1,
#  'Checkou-Checkout-Homepage-Log in': 1,
#  'Checkout-Career tracks-Homepage-Career track certificate': 1,
#  'Career tracks-Homepage-Career track certificate-Career tracks': 1,
#  'Homepage-Career track certificate-Career tracks-Career track certificate': 1,
#  'Career track certificate-Courses-Career track certificate-Upcoming courses': 1,
#  'Career track certificate-Upcoming courses-Courses-Homepage': 1,
#  'Upcoming courses-Courses-Homepage-Upcoming courses': 1,
#  'Courses-Homepage-Upcoming courses-Courses': 1,
#  'Homepage-Upcoming courses-Courses-Coupon': 1,
#  'Upcoming courses-Courses-Coupon-Log in': 1,
#  'Courses-Coupon-Log in-Homepage': 1,
#  'Homepage-Log in-Homepage-Career tracks': 1,
#  'Career tracks-Sign up-Log in-Homepage': 1,
#  'Log in-Resources center-Log in-Checkout': 1,
#  'Pricing-Homepage-Courses-Homepage': 1,
#  'Homepage-Pricing-Courses-Log in': 1,
#  'Sign up-Other-Career tracks-Sign up': 1,
#  'Other-Career tracks-Sign up-Coupon': 1,
#  'Pricing-Courses-Pricing-Upcoming courses': 1,
#  'Courses-Pricing-Upcoming courses-Courses': 1,
#  'Pricing-Upcoming courses-Courses-Upcoming courses': 1,
#  'Upcoming courses-Courses-Upcoming courses-Log in': 1,
#  'Courses-Upcoming courses-Log in-Courses': 1,
#  'Upcoming courses-Log in-Courses-Log in': 1,
#  'Courses-Coupon-Homepage-Courses': 1,
#  'Coupon-Log in-Instructors-Log in': 1,
#  'Log in-Instructors-Log in-Checkout': 1,
#  'Log in-Other-Sign up-Log in': 1,
#  'Sign up-Log in-Sign up-Career tracks': 1,
#  'Log in-Sign up-Career tracks-Sign up': 1,
#  'Career tracks-Sign up-Log in-Sign up': 1,
#  'Log in-Courses-Sign up-Courses': 1,
#  'Courses-Homepage-Course certificate-Coupon': 1,
#  'Log in-Courses-Sign up-Coupon': 1,
#  'Log in-Career track certificate-Homepage-Pricing': 1,
#  'Career track certificate-Homepage-Pricing-Career track certificate': 1,
#  'Sign up-Career track certificate-Sign up-Log in': 1,
#  'Pricing-Checkout-Pricing-Other': 1,
#  'Checkout-Pricing-Other-Pricing': 1,
#  'Pricing-Other-Pricing-Other': 1,
#  'Other-Pricing-Log in-Checkout': 1,
#  'Log in-Sign up-Checkout-Log in': 1,
#  'Log in-Coupon-Sign up-Homepage': 1,
#  'Log in-Homepage-Career track certificate-Checkout': 1,
#  'Pricing-Courses-Pricing-Career tracks': 1,
#  'Courses-Pricing-Career tracks-Sign up': 1,
#  'Pricing-Career tracks-Sign up-Homepage': 1,
#  'Career tracks-Sign up-Homepage-Pricing': 1,
#  'Other-Resources center-Log in-Resources center': 1,
#  'Resources center-Log in-Resources center-Homepage': 1,
#  'Log in-Resources center-Homepage-Resources center': 1,
#  'Resources center-Homepage-Resources center-Sign up': 1,
#  'Homepage-Resources center-Sign up-Log in': 1,
#  'Resources center-Sign up-Log in-Sign up': 1,
#  'Log in-Sign up-Log in-Other': 1,
#  'Sign up-Log in-Other-Log in': 1,
#  'Log in-Other-Log in-Resources center': 1,
#  'Other-Log in-Resources center-Coupon': 1,
#  'Career track certificate-Courses-Career track certificate-Resources center': 1,
#  'Courses-Career track certificate-Resources center-Career track certificate': 1,
#  'Resources center-Career track certificate-Resources center-Courses': 1,
#  'Career track certificate-Resources center-Courses-Career track certificate': 1,
#  'Resources center-Courses-Career track certificate-Coupon': 1,
#  'Coupon-Courses-Log in-Coupon': 1,
#  'Log in-Success stories-Log in-Success stories': 1,
#  'Success stories-Log in-Success stories-Pricing': 1,
#  'Log in-Success stories-Pricing-Success stories': 1,
#  'Success stories-Pricing-Success stories-Pricing': 1,
#  'Pricing-Success stories-Pricing-Homepage': 1,
#  'Success stories-Pricing-Homepage-Pricing': 1,
#  'Courses-Sign up-Checkout-Coupon': 1,
#  'Resources center-Career track certificate-Resources center-Log in': 1,
#  'Career track certificate-Resources center-Log in-Resources center': 1,
#  'Resources center-Log in-Resources center-Career track certificate': 1,
#  'Log in-Resources center-Career track certificate-Resources center': 1,
#  'Career track certificate-Resources center-Log in-Sign up': 1,
#  'Resources center-Log in-Sign up-Log in': 1,
#  'Sign up-Log in-Career track certificate-Sign up': 1,
#  'Log in-Career track certificate-Sign up-Career track certificate': 1,
#  'Sign up-Career track certificate-Homepage-Log in': 1,
#  'Career track certificate-Homepage-Log in-Checkout': 1,
#  'Resources center-Homepage-Sign up-Log in': 1,
#  'Courses-Course certificate-Courses-Sign up': 1,
#  'Courses-Sign up-Career tracks-Course certificate': 1,
#  'Sign up-Career tracks-Course certificate-Homepage': 1,
#  'Career tracks-Course certificate-Homepage-Career tracks': 1,
#  'Course certificate-Homepage-Career tracks-Courses': 1,
#  'Career tracks-Homepage-Courses-Homepage': 1,
#  'Courses-Homepage-Course certificate-Courses': 1,
#  'Homepage-Course certificate-Courses-Sign up': 1,
#  'Sign up-Courses-Homepage-Log in': 1,
#  'Courses-Homepage-Log in-Homepage': 1,
#  'Homepage-Pricing-Course certificate-Career track certificate': 1,
#  'Pricing-Course certificate-Career track certificate-Career tracks': 1,
#  'Course certificate-Career track certificate-Career tracks-Career track certificate': 1,
#  'Sign up-Career tracks-Homepage-Pricing': 1,
#  'Career tracks-Homepage-Pricing-Career tracks': 1,
#  'Homepage-Pricing-Career tracks-Career track certificate': 1,
#  'Pricing-Career tracks-Career track certificate-Career track certific': 1,
#  'Career tracks-Career track certificate-Career track certific-Checkout': 1,
#  'Courses-Career tracks-Courses-Sign up': 1,
#  'Career tracks-Courses-Sign up-Homepage': 1,
#  'Courses-Sign up-Homepage-Career track certificate': 1,
#  'Sign up-Homepage-Career track certificate-Sign up': 1,
#  'Homepage-Career track certificate-Sign up-Courses': 1,
#  'Career track certificate-Sign up-Courses-Upcoming courses': 1,
#  'Sign up-Courses-Upcoming courses-Resources center': 1,
#  'Courses-Upcoming courses-Resources center-Career track certificate': 1,
#  'Upcoming courses-Resources center-Career track certificate-Courses': 1,
#  'Resources center-Career track certificate-Courses-Homepage': 1,
#  'Career track certificate-Courses-Homepage-Sign up': 1,
#  'Homepage-Sign up-Courses-Career track certificate': 1,
#  'Sign up-Courses-Career track certificate-Career tracks': 1,
#  'Courses-Career track certificate-Career tracks-Courses': 1,
#  'Courses-Career tracks-Courses-Checkout': 1,
#  'Courses-Sign up-Courses-Career track certificate': 1,
#  'Sign up-Courses-Career track certificate-Courses': 1,
#  'Courses-Career track certificate-Homepage-Career tracks': 1,
#  'Career track certificate-Homepage-Career tracks-Career track certificate': 1,
#  'Homepage-Career tracks-Career track certificate-Career tracks': 1,
#  'Career track certificate-Career tracks-Career track certificate-Sign up': 1,
#  'Career tracks-Career track certificate-Sign up-Homepage': 1,
#  'Career track certificate-Sign up-Homepage-Coupon': 1,
#  'Homepage-Pricing-Homepage-Career track certificate': 1,
#  'Pricing-Homepage-Career track certificate-Sign up': 1,
#  'Sign up-Career track certificate-Career tracks-Courses': 1,
#  'Courses-Career tracks-Pricing-Homepage': 1,
#  'Pricing-Homepage-Career tracks-Courses': 1,
#  'Career tracks-Courses-Coupon-Homepage': 1,
#  'Courses-Coupon-Homepage-Sign up': 1,
#  'Coupon-Homepage-Sign up-Homepage': 1,
#  'Sign up-Courses-Homepage-Sign up': 1,
#  'Courses-Homepage-Sign up-Career tracks': 1,
#  'Homepage-Sign up-Career tracks-Sign up': 1,
#  'Homepage-Career tracks-Courses-Homepage': 1,
#  'Career tracks-Courses-Homepage-Sign up': 1,
#  'Courses-Homepage-Sign up-Checkout': 1,
#  'Log in-Homepage-Career track certificate-Homepage': 1,
#  'Homepage-Career track certificate-Homepage-Log in': 1,
#  'Homepage-Log in-Homepage-Pricing': 1,
#  'Checkout-Sign up-Homepage-Sign up': 1,
#  'Homepage-Courses-Sign up-Coupon': 1,
#  'Career tracks-Courses-Course certificate-Sign up': 1,
#  'Courses-Course certificate-Sign up-Courses': 1,
#  'Course certificate-Sign up-Courses-Sign up': 1,
#  'Courses-Sign up-Courses-Course certificate': 1,
#  'Sign up-Courses-Course certificate-Checkout': 1,
#  'Homepage-Career tracks-Homepage-Log in': 1,
#  'Career track certificate-Courses-Pricing-Homepage': 1,
#  'Pricing-Homepage-Pricing-Courses': 1,
#  'Homepage-Pricing-Courses-Sign up': 1,
#  'Pricing-Courses-Sign up-Homepage': 1,
#  'Sign up-Career tracks-Courses-Homepage': 1,
#  'Sign up-Log in-Homepage-Career tracks': 1,
#  'Log in-Homepage-Career tracks-Sign up': 1,
#  'Checkout-Resources center-Homepage-Course certificate': 1,
#  'Resources center-Homepage-Course certificate-Instructors': 1,
#  'Homepage-Course certificate-Instructors-Other': 1,
#  'Course certificate-Instructors-Other-Resources center': 1,
#  'Instructors-Other-Resources center-Career track certificate': 1,
#  'Other-Resources center-Career track certificate-Homepage': 1,
#  'Resources center-Career track certificate-Homepage-Career track certificate': 1,
#  'Career track certificate-Homepage-Career track certificate-Course certificate': 1,
#  'Homepage-Career track certificate-Course certificate-Career track certificate': 1,
#  'Career track certificate-Course certificate-Career track certificate-Coupon': 1,
#  'Career tracks-Courses-Career track certificate-Courses': 1,
#  'Courses-Career track certificate-Courses-Career tracks': 1,
#  'Career track certificate-Courses-Career tracks-Homepage': 1,
#  'Career tracks-Homepage-Career tracks-Other': 1,
#  'Homepage-Career tracks-Other-Career tracks': 1,
#  'Career tracks-Sign up-Homepage-Sign up': 1,
#  'Resources center-Other-Resources center-Blog': 1,
#  'Other-Resources center-Blog-Other': 1,
#  'Resources center-Blog-Other-Course certificate': 1,
#  'Blog-Other-Course certificate-Success stories': 1,
#  'Pricing-Log in-Homepage-Checkout': 1,
#  'Log in-Homepage-Checkout-Homepage': 1,
#  'Homepage-Checkout-Homepage-Log in': 1,
#  'Checkout-Homepage-Log in-Pricing': 1,
#  'Log in-Pricing-Checkout-Log in': 1,
#  'Homepage-Sign up-Career tracks-Log in': 1,
#  'Sign up-Career tracks-Log in-Checkout': 1,
#  'Other-Resources center-Homepage-Resources center': 1,
#  'Resources center-Homepage-Resources center-Log in': 1,
#  'Homepage-Resources center-Log in-Checkout': 1,
#  'Homepage-Pricing-Other-Pricing': 1,
#  'Pricing-Other-Pricing-Checkout': 1,
#  'Coupon-Success stories-Other-Success stories': 1,
#  'Career tracks-Sign up-Career track certificate-Pricing': 1,
#  'Sign up-Career track certificate-Pricing-Career tracks': 1,
#  'Career track certificate-Pricing-Career tracks-Sign up': 1,
#  'Sign up-Career tracks-Sign up-Courses': 1,
#  'Courses-Upcoming courses-Courses-Career tracks': 1,
#  'Courses-Career tracks-Pricing-Upcoming courses': 1,
#  'Career tracks-Pricing-Upcoming courses-Homepage': 1,
#  'Pricing-Upcoming courses-Homepage-Career track certificate': 1,
#  'Upcoming courses-Homepage-Career track certificate-Sign up': 1,
#  'Courses-Coupon-Course certificate-Courses': 1,
#  'Coupon-Course certificate-Courses-Coupon': 1,
#  'Course certificate-Courses-Coupon-Homepage': 1,
#  'Courses-Coupon-Homepage-Course certificate': 1,
#  'Coupon-Homepage-Course certificate-Coupon': 1,
#  'Course certificate-Homepage-Course certificate-Coupon': 1,
#  'Sign up-Homepage-Pricing-Homepage': 1,
#  'Homepage-Pricing-Sign up-Career tracks': 1,
#  'Pricing-Sign up-Career tracks-Sign up': 1,
#  'Homepage-Other-Pricing-Checkout': 1,
#  'Other-Pricing-Checkout-Courses': 1,
#  'Pricing-Checkout-Courses-Homepage': 1,
#  'Checkout-Courses-Homepage-Other': 1,
#  'Courses-Homepage-Other-Pricing': 1,
#  'Homepage-Other-Pricing-Courses': 1,
#  'Other-Pricing-Courses-Resources center': 1,
#  'Pricing-Courses-Resources center-Homepage': 1,
#  'Courses-Resources center-Homepage-Coupon': 1,
#  'Courses-Career tracks-Coupon-Instructors': 1,
#  'Courses-Sign up-Career tracks-Upcoming courses': 1,
#  'Sign up-Career tracks-Upcoming courses-Career tracks': 1,
#  'Career track certificate-Homepage-Sign up-Homepage': 1,
#  'Homepage-Sign up-Homepage-Career track certificate': 1,
#  'Sign up-Homepage-Career track certificate-Career tracks': 1,
#  'Career tracks-Career track certificate-Career tracks-Pricing': 1,
#  'Career track certificate-Career tracks-Pricing-Career track certificate': 1,
#  'Career tracks-Pricing-Career track certificate-Homepage': 1,
#  'Pricing-Career track certificate-Homepage-Coupon': 1,
#  'Homepage-Courses-Career track certificate-Sign up': 1,
#  'Courses-Career track certificate-Sign up-Career track certificate': 1,
#  'Checkout-Log in-Checkout-Homepage': 1,
#  'Homepage-Pricing-Homepage-Career tracks': 1,
#  'Courses-Homepage-Courses-Upcoming courses': 1,
#  'Homepage-Courses-Upcoming courses-Courses': 1,
#  'Courses-Pricing-Homepage-Resources center': 1,
#  'Pricing-Homepage-Resources center-Pricing': 1,
#  'Homepage-Resources center-Pricing-Resources center': 1,
#  'Resources center-Pricing-Resources center-Career track certificate': 1,
#  'Pricing-Resources center-Career track certificate-Resources center': 1,
#  'Career track certificate-Courses-Career track certificate-Career tracks': 1,
#  'Upcoming courses-Courses-Pricing-Courses': 1,
#  'Courses-Pricing-Courses-Other': 1,
#  'Pricing-Courses-Other-Pricing': 1,
#  'Courses-Other-Pricing-Courses': 1,
#  'Other-Pricing-Courses-Upcoming courses': 1,
#  'Pricing-Courses-Upcoming courses-Resources center': 1,
#  'Courses-Upcoming courses-Resources center-Courses': 1,
#  'Upcoming courses-Resources center-Courses-Pricing': 1,
#  'Resources center-Courses-Pricing-Resources center': 1,
#  'Courses-Pricing-Resources center-Instructors': 1,
#  'Pricing-Resources center-Instructors-Pricing': 1,
#  'Resources center-Instructors-Pricing-Checkout': 1,
#  'Instructors-Pricing-Checkout-Pricing': 1,
#  'Career tracks-Courses-Career tracks-Upcoming courses': 1,
#  'Courses-Career tracks-Upcoming courses-Career tracks': 1,
#  'Career tracks-Upcoming courses-Career tracks-Coupon': 1,
#  'Homepage-Career track certificate-Homepage-Resources center': 1,
#  'Career track certificate-Homepage-Resources center-Courses': 1,
#  'Homepage-Resources center-Courses-Career tracks': 1,
#  'Resources center-Courses-Career tracks-Course certificate': 1,
#  'Courses-Career tracks-Course certificate-Courses': 1,
#  'Career tracks-Course certificate-Courses-Career tracks': 1,
#  'Career tracks-Courses-Career tracks-Course certificate': 1,
#  'Course certificate-Courses-Career tracks-Course certificate': 1,
#  'Courses-Career tracks-Course certificate-Checkout': 1,
#  'Career track certificate-Coupon-Homepage-Career track certificate': 1,
#  'Coupon-Homepage-Career track certificate-Coupon': 1,
#  'Homepage-Career track certificate-Coupon-Career track certificate': 1,
#  'Career track certificate-Coupon-Career track certificate-Coupon': 1,
#  'Homepage-Sign up-Other-Coupon': 1,
#  'Courses-Career tracks-Sign up-Checkout': 1,
#  'Career tracks-Sign up-Checkout-Career tracks': 1,
#  'Sign up-Checkout-Career tracks-Pricing': 1,
#  'Checkout-Career tracks-Pricing-Checkout': 1,
#  'Career tracks-Pricing-Checkout-Coupon': 1,
#  'Career tracks-Courses-Homepage-Pricing': 1,
#  'Homepage-Pricing-Courses-Career tracks': 1,
#  'Career tracks-Pricing-Checkout-Pricing': 1,
#  'Pricing-Checkout-Pricing-Courses': 1,
#  'Checkout-Pricing-Courses-Career tracks': 1,
#  'Course certificate-Career tracks-Career track certificate-Course certificate': 1,
#  'Career tracks-Career track certificate-Course certificate-Upcoming courses': 1,
#  'Career track certificate-Course certificate-Upcoming courses-Course certificate': 1,
#  'Course certificate-Upcoming courses-Course certificate-Courses': 1,
#  'Upcoming courses-Course certificate-Courses-Career tracks': 1,
#  'Course certificate-Courses-Career tracks-Upcoming courses': 1,
#  'Courses-Career tracks-Upcoming courses-Other': 1,
#  'Career tracks-Upcoming courses-Other-Career tracks': 1,
#  'Upcoming courses-Other-Career tracks-Pricing': 1,
#  'Other-Career tracks-Pricing-Course certificate': 1,
#  'Career tracks-Pricing-Course certificate-Pricing': 1,
#  'Pricing-Course certificate-Pricing-Career track certificate': 1,
#  'Course certificate-Pricing-Career track certificate-Other': 1,
#  'Pricing-Career track certificate-Other-Career tracks': 1,
#  'Career track certificate-Other-Career tracks-Pricing': 1,
#  'Other-Career tracks-Pricing-Coupon': 1,
#  'Career tracks-Other-Career tracks-Courses': 1,
#  'Other-Career tracks-Courses-Homepage': 1,
#  'Career tracks-Courses-Homepage-Log in': 1,
#  'Other-Blog-Other-Homepage': 1,
#  'Blog-Other-Homepage-Blog': 1,
#  'Other-Homepage-Blog-Coupon': 1,
#  'Sign up-Coupon-Checkout-Pricing': 1,
#  'Courses-Career tracks-Checkout-Pricing': 1,
#  'Courses-Other-Course certificate-Coupon': 1,
#  'Homepage-Courses-Sign up-Pricing': 1,
#  'Sign up-Homepage-Pricing-Log in': 1,
#  'Pricing-Log in-Other-Pricing': 1,
#  'Sign up-Courses-Log in-Courses': 1,
#  'Coupon-Homepage-Checkout-Pricing': 1,
#  'Homepage-Checkout-Pricing-Checkout': 1,
#  'Homepage-Career tracks-Courses-Resources center': 1,
#  'Career tracks-Courses-Resources center-Coupon': 1,
#  'Homepage-Courses-Sign up-Career track certificate': 1,
#  'Courses-Sign up-Career track certificate-Sign up': 1,
#  'Career track certificate-Sign up-Career track certificate-Courses': 1,
#  'Sign up-Career track certificate-Courses-Career track certificate': 1,
#  'Career track certificate-Courses-Career track certificate-Sign up': 1,
#  'Courses-Career track certificate-Sign up-Checkout': 1,
#  'Courses-Career tracks-Other-Career tracks': 1,
#  'Career tracks-Other-Career tracks-Upcoming courses': 1,
#  'Other-Career tracks-Upcoming courses-Career track certificate': 1,
#  'Career tracks-Upcoming courses-Career track certificate-Upcoming courses': 1,
#  'Upcoming courses-Career track certificate-Upcoming courses-Career track certificate': 1,
#  'Career track certificate-Upcoming courses-Career track certificate-Coupon': 1,
#  'Homepage-Pricing-Career track certificate-Homepage': 1,
#  'Pricing-Career track certificate-Homepage-Pricing': 1,
#  'Pricing-Checkout-Homepage-Career track certificate': 1,
#  'Checkout-Homepage-Career track certificate-Career tracks': 1,
#  'Homepage-Career track certificate-Career tracks-Pricing': 1,
#  'Career track certificate-Career tracks-Pricing-Checkout': 1,
#  'Courses-Homepage-Career tracks-Sign up': 1,
#  'Sign up-Homepage-Courses-Checkout': 1,
#  'Course certificate-Courses-Course certificate-Resources center': 1,
#  ...}
